# %%
import Constants as c           # constants
import polars as pl             # polars
import os                       # for reading local files and folders
import zipfile                  # for handling zip files
from collections import Counter # for stats analysis on the dataframe  
import math                     # for math functions
import matplotlib.pyplot as plt # for plotting
import statistics as stats      # for statistics functions

# %% [markdown]
# Extract only the data with the correct latitude and longitude values</br>
# This operation takes roughly 15-20 seconds per csv file (tested on csv files with > 1 million rows)</br>

# %%
final_df = pl.DataFrame()

# list all the valid files
valid_filenames = [f for f in os.listdir(c.FOLDER_PATH) if f.startswith('AIS')]
valid_filenames.sort()
csv_filenames = [f.removesuffix('.csv') for f in valid_filenames if f.endswith('.csv')]
zip_filenames = [f.removesuffix('.zip') for f in valid_filenames if f.endswith('.zip')]

already_unzipped = [f + '.zip' for f in csv_filenames]
stored_names, to_unzip_filenames = [], []

if c.LOG_FILE_NAME not in os.listdir(c.FOLDER_PATH):
    with open(file=c.FOLDER_PATH + c.LOG_FILE_NAME, mode='w') as f:
        for filename in already_unzipped:
            f.write(filename + '\n')
        print('log file created! Run this code again to extact the zip files and import them into a dataframe')

else:
    with open(file=c.FOLDER_PATH + c.LOG_FILE_NAME, mode='r+') as f:
        stored_names = [line.rstrip() for line in f]
        to_unzip_filenames = [f + '.zip' for f in zip_filenames if not(f in stored_names)]
        for zip_name in to_unzip_filenames:
            print(f'Unzipping file {zip_name}...')
            with zipfile.ZipFile(c.FOLDER_PATH + zip_name, 'r') as z:
                z.extractall(c.FOLDER_PATH)
                print(f'Writing filename: {zip_name} to log file')
                f.write(zip_name + '\n')
        for csv_name in [f for f in valid_filenames if f.startswith('AIS') and f.endswith('.csv')]:
            print(f'Importing and cleaning csv: {csv_name}')
            full_df = pl.read_csv(source=c.FOLDER_PATH + csv_name,
                                try_parse_dates=True,
                                low_memory = True,
                                quote_char=None
                                )
            filtered_df = full_df.filter(
                                        (pl.col('LAT').is_between(c.LAT_MIN, c.LAT_MAX, closed='none')) &
                                        (pl.col('LON').is_between(c.LON_MIN, c.LON_MAX, closed='none'))
                                        )

            final_df = pl.concat([final_df, filtered_df], how='vertical')

        for filename in to_unzip_filenames:
            print(f'Deleting unzipped file {filename}')
            os.unlink(c.FOLDER_PATH + filename)

print(final_df.shape)
# Out:
# Importing and cleaning csv: AIS_2019_01_01.csv
# Importing and cleaning csv: AIS_2019_01_02.csv
# Importing and cleaning csv: AIS_2019_01_03.csv
# Importing and cleaning csv: AIS_2019_01_04.csv
# Importing and cleaning csv: AIS_2019_01_05.csv
# Importing and cleaning csv: AIS_2019_01_06.csv
# Importing and cleaning csv: AIS_2019_01_07.csv
# Importing and cleaning csv: AIS_2019_01_08.csv
# Importing and cleaning csv: AIS_2019_01_09.csv
# Importing and cleaning csv: AIS_2019_01_10.csv
# Importing and cleaning csv: AIS_2019_01_11.csv
# Importing and cleaning csv: AIS_2019_01_12.csv
# Importing and cleaning csv: AIS_2019_01_13.csv
# Importing and cleaning csv: AIS_2019_01_14.csv
# Importing and cleaning csv: AIS_2019_01_15.csv
# Importing and cleaning csv: AIS_2019_01_16.csv
# Importing and cleaning csv: AIS_2019_01_17.csv
# Importing and cleaning csv: AIS_2019_01_18.csv
# Importing and cleaning csv: AIS_2019_01_19.csv
# Importing and cleaning csv: AIS_2019_01_20.csv
# Importing and cleaning csv: AIS_2019_01_21.csv
# Importing and cleaning csv: AIS_2019_01_22.csv
# Importing and cleaning csv: AIS_2019_01_23.csv
# Importing and cleaning csv: AIS_2019_01_24.csv
# Importing and cleaning csv: AIS_2019_01_25.csv
# Importing and cleaning csv: AIS_2019_01_26.csv
# Importing and cleaning csv: AIS_2019_01_27.csv
# Importing and cleaning csv: AIS_2019_01_28.csv
# Importing and cleaning csv: AIS_2019_01_29.csv
# Importing and cleaning csv: AIS_2019_01_30.csv
# Importing and cleaning csv: AIS_2019_01_31.csv
# Importing and cleaning csv: AIS_2019_02_01.csv
# Importing and cleaning csv: AIS_2019_02_02.csv
# Importing and cleaning csv: AIS_2019_02_03.csv
# Importing and cleaning csv: AIS_2019_02_04.csv
# Importing and cleaning csv: AIS_2019_02_05.csv
# Importing and cleaning csv: AIS_2019_02_06.csv
# Importing and cleaning csv: AIS_2019_02_07.csv
# Importing and cleaning csv: AIS_2019_02_08.csv
# Importing and cleaning csv: AIS_2019_02_09.csv
# Importing and cleaning csv: AIS_2019_02_10.csv
# Importing and cleaning csv: AIS_2019_02_11.csv
# Importing and cleaning csv: AIS_2019_02_12.csv
# Importing and cleaning csv: AIS_2019_02_13.csv
# Importing and cleaning csv: AIS_2019_02_14.csv
# Importing and cleaning csv: AIS_2019_02_15.csv
# Importing and cleaning csv: AIS_2019_02_16.csv
# Importing and cleaning csv: AIS_2019_02_17.csv
# Importing and cleaning csv: AIS_2019_02_18.csv
# Importing and cleaning csv: AIS_2019_02_19.csv
# Importing and cleaning csv: AIS_2019_02_20.csv
# Importing and cleaning csv: AIS_2019_02_21.csv
# Importing and cleaning csv: AIS_2019_02_22.csv
# Importing and cleaning csv: AIS_2019_02_23.csv
# Importing and cleaning csv: AIS_2019_02_24.csv
# Importing and cleaning csv: AIS_2019_02_25.csv
# Importing and cleaning csv: AIS_2019_02_26.csv
# Importing and cleaning csv: AIS_2019_02_27.csv
# Importing and cleaning csv: AIS_2019_02_28.csv
# Importing and cleaning csv: AIS_2019_03_01.csv
# Importing and cleaning csv: AIS_2019_03_02.csv
# Importing and cleaning csv: AIS_2019_03_03.csv
# Importing and cleaning csv: AIS_2019_03_04.csv
# Importing and cleaning csv: AIS_2019_03_05.csv
# Importing and cleaning csv: AIS_2019_03_06.csv
# Importing and cleaning csv: AIS_2019_03_07.csv
# Importing and cleaning csv: AIS_2019_03_08.csv
# Importing and cleaning csv: AIS_2019_03_09.csv
# Importing and cleaning csv: AIS_2019_03_10.csv
# Importing and cleaning csv: AIS_2019_03_11.csv
# Importing and cleaning csv: AIS_2019_03_12.csv
# Importing and cleaning csv: AIS_2019_03_13.csv
# Importing and cleaning csv: AIS_2019_03_14.csv
# Importing and cleaning csv: AIS_2019_03_15.csv
# Importing and cleaning csv: AIS_2019_03_16.csv
# Importing and cleaning csv: AIS_2019_03_17.csv
# Importing and cleaning csv: AIS_2019_03_18.csv
# Importing and cleaning csv: AIS_2019_03_19.csv
# Importing and cleaning csv: AIS_2019_03_20.csv
# Importing and cleaning csv: AIS_2019_03_21.csv
# Importing and cleaning csv: AIS_2019_03_22.csv
# Importing and cleaning csv: AIS_2019_03_23.csv
# Importing and cleaning csv: AIS_2019_03_24.csv
# Importing and cleaning csv: AIS_2019_03_25.csv
# Importing and cleaning csv: AIS_2019_03_26.csv
# Importing and cleaning csv: AIS_2019_03_27.csv
# Importing and cleaning csv: AIS_2019_03_28.csv
# Importing and cleaning csv: AIS_2019_03_29.csv
# Importing and cleaning csv: AIS_2019_03_30.csv
# Importing and cleaning csv: AIS_2019_03_31.csv
# Importing and cleaning csv: AIS_2019_04_01.csv
# Importing and cleaning csv: AIS_2019_04_02.csv
# Importing and cleaning csv: AIS_2019_04_03.csv
# Importing and cleaning csv: AIS_2019_04_04.csv
# Importing and cleaning csv: AIS_2019_04_05.csv
# Importing and cleaning csv: AIS_2019_04_06.csv
# Importing and cleaning csv: AIS_2019_04_07.csv
# Importing and cleaning csv: AIS_2019_04_08.csv
# Importing and cleaning csv: AIS_2019_04_09.csv
# Importing and cleaning csv: AIS_2019_04_10.csv
# Importing and cleaning csv: AIS_2019_04_11.csv
# Importing and cleaning csv: AIS_2019_04_12.csv
# Importing and cleaning csv: AIS_2019_04_13.csv
# Importing and cleaning csv: AIS_2019_04_14.csv
# Importing and cleaning csv: AIS_2019_04_15.csv
# Importing and cleaning csv: AIS_2019_04_16.csv
# Importing and cleaning csv: AIS_2019_04_17.csv
# Importing and cleaning csv: AIS_2019_04_18.csv
# Importing and cleaning csv: AIS_2019_04_19.csv
# Importing and cleaning csv: AIS_2019_04_20.csv
# Importing and cleaning csv: AIS_2019_04_21.csv
# Importing and cleaning csv: AIS_2019_04_22.csv
# Importing and cleaning csv: AIS_2019_04_23.csv
# Importing and cleaning csv: AIS_2019_04_24.csv
# Importing and cleaning csv: AIS_2019_04_25.csv
# Importing and cleaning csv: AIS_2019_04_26.csv
# Importing and cleaning csv: AIS_2019_04_27.csv
# Importing and cleaning csv: AIS_2019_04_28.csv
# Importing and cleaning csv: AIS_2019_04_29.csv
# Importing and cleaning csv: AIS_2019_04_30.csv
# Importing and cleaning csv: AIS_2019_05_01.csv
# Importing and cleaning csv: AIS_2019_05_02.csv
# Importing and cleaning csv: AIS_2019_05_03.csv
# Importing and cleaning csv: AIS_2019_05_04.csv
# Importing and cleaning csv: AIS_2019_05_05.csv
# Importing and cleaning csv: AIS_2019_05_06.csv
# Importing and cleaning csv: AIS_2019_05_07.csv
# Importing and cleaning csv: AIS_2019_05_08.csv
# Importing and cleaning csv: AIS_2019_05_09.csv
# Importing and cleaning csv: AIS_2019_05_10.csv
# Importing and cleaning csv: AIS_2019_05_11.csv
# Importing and cleaning csv: AIS_2019_05_12.csv
# Importing and cleaning csv: AIS_2019_05_13.csv
# Importing and cleaning csv: AIS_2019_05_14.csv
# Importing and cleaning csv: AIS_2019_05_15.csv
# Importing and cleaning csv: AIS_2019_05_16.csv
# Importing and cleaning csv: AIS_2019_05_17.csv
# Importing and cleaning csv: AIS_2019_05_18.csv
# Importing and cleaning csv: AIS_2019_05_19.csv
# Importing and cleaning csv: AIS_2019_05_20.csv
# Importing and cleaning csv: AIS_2019_05_21.csv
# Importing and cleaning csv: AIS_2019_05_22.csv
# Importing and cleaning csv: AIS_2019_05_23.csv
# Importing and cleaning csv: AIS_2019_05_24.csv
# Importing and cleaning csv: AIS_2019_05_25.csv
# Importing and cleaning csv: AIS_2019_05_26.csv
# Importing and cleaning csv: AIS_2019_05_27.csv
# Importing and cleaning csv: AIS_2019_05_28.csv
# Importing and cleaning csv: AIS_2019_05_29.csv
# Importing and cleaning csv: AIS_2019_05_30.csv
# (9461383, 17)

# %% [markdown]
# Separate code snippet used for exporting the final dataframe as a csv file.</br>
# This is necessary as the above code snippet takes a while to read and filter several csv files.</br>
# By exporting the resulting df as a csv file it's possible import it again for the following part of this notebook.</br>

# %%
#OUTPUT_PATH = os.getcwd() # returns current working dir
OUTPUT_PATH = c.FOLDER_PATH
FILE_NAME = '2019_01-05.csv' #specify file name (.csv extension necessary)

# %%
# export the full, uncleaned csv for backup purposes
final_df.write_csv(OUTPUT_PATH + '/' + FILE_NAME)

print(f"Dataframe shape: {final_df.shape}")
# Out:
# Dataframe shape: (9461383, 17)

# %% [markdown]
# Read the csv file and use it as the final data source</br>
# (The code snippet below should be used only if the code snippet #2 was not executed)

# %%
# read csv
final_df = pl.read_csv(OUTPUT_PATH + FILE_NAME)
print(f'Rows, col before: {final_df.shape}')
final_df = final_df.unique()
print(f'Rows, col after: {final_df.shape}')
# Out:
# Rows, col before: (9461383, 17)
# Rows, col after: (9458822, 17)

# %% [markdown]
# Some stats about the imported dataframe</br>
# In order to make the histogram below, occurrencies are rounded to the top hundred (ex: 33 -> 100, 244 -> 300, etc...)</br>
# This is done in order to have an idea about how many ships have negligible amount of records.</br>
# In the following code snippet the threshold is set to 100 and consequently all vessels with less than 100 data points are removed from the dataset</br>

# %%
# Extract all the unique MMSIs
unique_mmsis = final_df['MMSI'].unique()

# Calculate the exact number of entries for each ship

vessels_entries_dict = dict(Counter(final_df['MMSI'].to_list()))
vessel_entries = list(vessels_entries_dict.values())
vessel_entries.sort()
rounded_vessel_entries = [math.ceil(x/100) * 100 for x in vessel_entries]

print(f"Avg entries for each vessel {stats.mean(vessel_entries)}")
print(f"Variance: {stats.variance(vessel_entries)}")
print(f"Standard Deviation: {stats.stdev(vessel_entries)}")
print(f"Max entries found for the same ship: {vessel_entries[-1]}")
print(f"Min entries found for the same ship: {vessel_entries[0]}")

n, bins, patches = plt.hist(x=rounded_vessel_entries, bins='auto', color='orange', edgecolor = 'black')
# Out:
# Avg entries for each vessel 12111.167733674776
# Variance: 516905995.52952164
# Standard Deviation: 22735.566751887265
# Max entries found for the same ship: 143452
# Min entries found for the same ship: 1

# %% [markdown]
# Remove ships with not enough points

# %%
THRESHOLD = int(stats.mean(vessel_entries) * 0.1)  # 10% of the average entries per ship
print(f'Threshold: {THRESHOLD} rows')
# find the MMSIs of all the ships with more than THRESHOLD points
mmsi_to_be_kept = [x for x in vessels_entries_dict.keys() if vessels_entries_dict[x] > THRESHOLD]
print(f"Final dataframe len: {final_df.shape[0]}, num of vessels: {len(vessel_entries)}, num of vessels: {len(mmsi_to_be_kept)}")

clean_df = pl.DataFrame()
for mmsi in mmsi_to_be_kept:    
    temp_df = final_df.filter(pl.col('MMSI') == mmsi)
    clean_df = pl.concat([clean_df, temp_df])
    
print(f"Cleaned dataframe len: {clean_df.shape[0]}, num of vessels: {len(clean_df['MMSI'].unique())}")
print(f'Percentage of row dropped/total rows = {round((final_df.shape[0] - clean_df.shape[0])/final_df.shape[0] * 100, 4)}%')
# Out:
# Threshold: 1211 rows
# Final dataframe len: 9458822, num of vessels: 781, num of vessels: 494
# Cleaned dataframe len: 9383271, num of vessels: 494
# Percentage of row dropped/total rows = 0.7987%

# %% [markdown]
# Export the cleaned dataframe in order to have a backup copy in a csv file

# %%
#OUTPUT_PATH = os.getcwd()
OUTPUT_PATH = c.FOLDER_PATH
clean_df.write_csv(OUTPUT_PATH + '/cleaned_' + FILE_NAME)

print(f"Dataframe shape: {clean_df.shape}")
# Out:
# Dataframe shape: (9383271, 17)

# %% [markdown]
# Create a new histogram using the "cleaned" data from the clean_df

# %%
clean_vessel_entries = list(Counter(clean_df['MMSI'].to_list()).values())

rounded_clean_vessels_entries = [math.ceil(x/100) * 100 for x in clean_vessel_entries]

print(f"Avg entries for each vessel {stats.mean(clean_vessel_entries)}")
print(f"Variance: {stats.variance(clean_vessel_entries)}")
print(f"Standard Deviation: {stats.stdev(clean_vessel_entries)}")
print(f"Max entries found for the same ship: {max(clean_vessel_entries)}")
print(f"Min entries found for the same ship: {min(clean_vessel_entries)}")

n, bins, patches = plt.hist(x=rounded_clean_vessels_entries, bins='auto', color='green', edgecolor = 'black', )
# Out:
# Avg entries for each vessel 18994.475708502025
# Variance: 688565503.6495101
# Standard Deviation: 26240.53169525172
# Max entries found for the same ship: 143452
# Min entries found for the same ship: 1215

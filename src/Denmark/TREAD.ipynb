# %%
# imports
import Constants as c                           # constanst
import Functions as f                           # functions
import polars as pl                             # polars
import pandas as p                              # pandas
import numpy as np                              # numpy
from tqdm import tqdm
from sklearn.cluster import DBSCAN              # DBSCAN algorithm
from sklearn.cluster import HDBSCAN             # HDBSCAN algorithm
import hdbscan as hdbs                          # improved (faster) HDBSCAN https://github.com/scikit-learn-contrib/hdbscan, https://joss.theoj.org/papers/10.21105/joss.00205
import matplotlib.pyplot as plt                 # plot
import gc                                       # garbage collector
import sys
from scipy.spatial import ConvexHull            # ConvexHulls for clusters
from shapely.geometry.polygon import Polygon    # for operations on clusters
import statistics as s                          # for statistics
import pickle                                   # for exporting the final result

# map plotting
import shapely as shpl               
import plotly.express as px
import plotly.offline as po
import plotly.graph_objects as go

# %% [markdown]
# Import source csv into a dataframe

# %%
FILE_NAME = 'cleaned_denmark_2023-06-05_point-based.parquet'
clean_df = pl.read_parquet(c.FOLDER_PATH + FILE_NAME)
print(f'Dataframe shape: {clean_df.shape}')
print(clean_df.columns)
print(clean_df.shape)
display(clean_df.head(1))
# Out:
# Dataframe shape: (8791456, 18)
# ['BaseDateTime', 'MMSI', 'LAT', 'LON', 'Status', 'SOG', 'COG', 'Heading', 'IMO', 'CallSign', 'VesselName', 'VesselType', 'Cargo', 'Width', 'Length', 'Draft', '__index_level_0__', 'IsClassA']
# (8791456, 18)
# shape: (1, 18)
# ┌─────────────────┬───────────┬─────────┬─────────┬───┬────────┬───────┬────────────────┬──────────┐
# │ BaseDateTime    ┆ MMSI      ┆ LAT     ┆ LON     ┆ … ┆ Length ┆ Draft ┆ __index_level_ ┆ IsClassA │
# │ ---             ┆ ---       ┆ ---     ┆ ---     ┆   ┆ ---    ┆ ---   ┆ 0__            ┆ ---      │
# │ datetime[ns]    ┆ i64       ┆ f64     ┆ f64     ┆   ┆ f64    ┆ f64   ┆ ---            ┆ bool     │
# │                 ┆           ┆         ┆         ┆   ┆        ┆       ┆ i64            ┆          │
# ╞═════════════════╪═══════════╪═════════╪═════════╪═══╪════════╪═══════╪════════════════╪══════════╡
# │ 2023-05-06      ┆ 205096000 ┆ 55.6581 ┆ 5.47449 ┆ … ┆ 34.0   ┆ 5.2   ┆ 1299           ┆ true     │
# │ 13:11:54        ┆           ┆         ┆         ┆   ┆        ┆       ┆                ┆          │
# └─────────────────┴───────────┴─────────┴─────────┴───┴────────┴───────┴────────────────┴──────────┘

# %% [markdown]
# Columns dtypes optimization in order to reduce RAM usage <br>
# (=casting to smaller dtypes)

# %%
display(f'Dataframe size in RAM {clean_df.estimated_size()/1_000_000_000:.3f} GB')
# Out:
# 'Dataframe size in RAM 1.084 GB'

# %%
optimized_df = clean_df.select(
    # MMSI - 9 digits number, converted from int64 to int32
    pl.col('MMSI').cast(pl.Int32),
    # BaseDateTime - from str to datetime
    pl.col('BaseDateTime').cast(pl.Datetime(time_unit='ms')),
    # LAT - No change in datatype, but accuracy is reduced
    pl.col('LAT').round(4),
    # LON - No change in datatype, but accuracy is reduced
    pl.col('LON').round(4),

    # No action
    pl.col('SOG'),
    pl.col('COG'),
    pl.col('Heading'),
    pl.col('VesselName'),
    pl.col('IMO'),
    pl.col('CallSign'),
    pl.col('VesselType'),
    pl.col('Status'),

    # Choose a smaller dtype to save space
    pl.col('Length').cast(pl.Int16),
    pl.col('Width').cast(pl.Int16),
    pl.col('Draft').cast(pl.Float32),

    # No action
    pl.col('Cargo'),
    pl.col('IsClassA')
)

display(f'New dataframe size in RAM {optimized_df.estimated_size()/1_000_000_000:.3f} GB')
# Out:
# 'New dataframe size in RAM 0.837 GB'

# %% [markdown]
# Source: Pallotta, G., Vespe, M., & Bryan, K. (2013). Vessel Pattern Knowledge Discovery from AIS Data: A Framework for Anomaly Detection and Route Prediction. Entropy, 15(12), 2218–2245. https://doi.org/10.3390/e15062218
#
# ‌TREAD algorithm (pages 2223-2231)

# %%
# From the complete db, select only the necessary columns
optimized_df = optimized_df.select(['MMSI', 'BaseDateTime', 'LAT', 'LON', 'SOG', 'COG', 'Heading',
                            'VesselName', 'VesselType', 'Status', 'Length',
                            'Width', 'Draft', 'IsClassA'])
# Drop duplicates, just in case
optimized_df = optimized_df.unique(subset=['MMSI', 'BaseDateTime'], keep='first')
optimized_df = optimized_df.sort('BaseDateTime')

reference_list_of_mmsi = optimized_df['MMSI'].unique().to_list()
reference_list_of_mmsi.sort()

V_s = [] # List of dataframes. Each dataframe represents a Vessel (and its journey)

# for each ship
for mmsi in tqdm(reference_list_of_mmsi, desc='Processing vessels'):
    # Extract all points generated by the ship
    appendDF = optimized_df.filter(pl.col('MMSI') == mmsi)
    # Add a new column for storing the average speed between the current point and the previous
    appendDF = appendDF.with_columns(pl.lit(None).alias('Avg_Speed').cast(pl.Float64))
    if len(appendDF) <= 1:
        print(f'{mmsi} has less than 2 points')
    # next step: calculate the avg_speed (distance/time) in order to find stationary points. (SOG is not always reliable)
    # for the distance, the great-circle distance is used in order to account for earth curvature
    if len(appendDF) > 1:
        # save a shifted-by-one-row version of the db, so that "previous" points can be joined with "current" points
        shifted_lats = appendDF['LAT'].shift(1)
        shifted_lons = appendDF['LON'].shift(1)
        shifted_times = appendDF['BaseDateTime'].shift(1)
        # the resulting df has (for each row) a pair of points. The left one is antecedent to the right one
        pairsOfPointsDF = appendDF.with_columns([
            shifted_lats.alias('LAT_left'), # new column called LAT_left
            shifted_lons.alias('LON_left'), # new column called LON_left
            shifted_times.alias('BaseDateTime_left') # new column called BaseDateTime_left
        ]).rename({
            'LAT': 'LAT_right', # rename the original columns of appendDF
            'LON': 'LON_right',
            'BaseDateTime': 'BaseDateTime_right'
        })
        # Remove the first row that has null values due to the shift
        pairsOfPointsDF = pairsOfPointsDF.slice(1)
        # calculate average speed for each row of the 'pairsOfPointsDF' df (each row represents a pair of points)
        # add a new column that holds the time difference between the two points of the row
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            (pl.col('BaseDateTime_right').cast(pl.Datetime) - pl.col('BaseDateTime_left')
            .cast(pl.Datetime)).dt.total_seconds().alias('DeltaTime')
        )
        # add a new column that holds the distance (in meters) between the two points of the same row
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            f.great_circle_distance_vectorized(
                lat_left=pairsOfPointsDF['LAT_left'],
                lon_left=pairsOfPointsDF['LON_left'],
                lat_right=pairsOfPointsDF['LAT_right'],
                lon_right=pairsOfPointsDF['LON_right']
            ).alias('Distance') 
        )

        # Calculate average speed (in m/s)
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            (pl.col('Distance') / pl.col('DeltaTime')).alias('Speed')
        )
        # sometimes a vessel can stop reporting its position and re-appear too far away from its last known location.
        # In this case it makes little sense to calculate the avg_speed. (np.nan multiplied by any number returns np.nan)

        # condition used to determine if the ship is "lost"
        lost_condition = pl.col('DeltaTime') > c.LOST_TIME_THRESHOLD_SECONDS
        # another codition used to determine if the ship has left the domain for a significant amount of time
        exit_condition = pl.col('DeltaTime') > c.EXIT_TIME_THRESHOLD_HOURS
        # the avg_speed of the points following the ones considered "lost" 
        # (which includes also vessels that satisfy the Exit condition) is set to nan
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            pl.when(lost_condition)
            .then(None)
            .otherwise(pl.col('Speed'))
            .alias('Speed')
        )
        # any nan point of the 'Speed' column is set to the corresponging 'SOG' value (if available and reliable)
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            pl.when(pl.col('Speed').is_null() & (pl.col('SOG') < c.ABSURD_SPEED_THRESHOLD))
            .then(pl.col('SOG') / c.KNOTS_CONST)
            .when(pl.col('Speed').is_null())
            .then(pl.col('Distance') / pl.col('DeltaTime'))
            .otherwise(pl.col('Speed'))
            .alias('Speed')
        )
        # Add a new column for storing the status of the ship (according to TREAD algorithm, see above)
        pairsOfPointsDF = pairsOfPointsDF.with_columns(pl.lit(None).cast(pl.String).alias('EstimatedStatus'))

        # set the status of the last and first points before (lost) and after (return) a small interruption
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            pl.when(lost_condition.shift(-1, fill_value=False))
            .then(pl.lit('lost'))
            .otherwise(pl.col('EstimatedStatus'))
            .alias('EstimatedStatus')
        )
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            pl.when(lost_condition)
            .then(pl.lit('return'))
            .otherwise(pl.col('EstimatedStatus'))
            .alias('EstimatedStatus')
        )

        # set the status of the last and first points before (exit) and after (entry) a big interruption
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            pl.when(exit_condition.shift(-1, fill_value=False))
            .then(pl.lit('exit'))
            .otherwise(pl.col('EstimatedStatus'))
            .alias('EstimatedStatus')
        )
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            pl.when(exit_condition)
            .then(pl.lit('entry'))
            .otherwise(pl.col('EstimatedStatus'))
            .alias('EstimatedStatus')
        )

        # convert the speed from meters to nautical knots and round it to 2 decimal values
        pairsOfPointsDF = pairsOfPointsDF.with_columns(
            (pl.col('Speed') * c.KNOTS_CONST).round(2).alias('Speed')
        )

        speed_values = pairsOfPointsDF.select(['BaseDateTime_right', 'Speed', 'EstimatedStatus'])
        # Rename BaseDateTime_right back to BaseDateTime to match appendDF's column name for joining
        speed_values = speed_values.rename({'BaseDateTime_right': 'BaseDateTime'})

        # Join the speed values and estimated status back to the appendDF
        appendDF = appendDF.join(
            speed_values,
            on='BaseDateTime',
            how='left'
        )
        # Update the Avg_Speed column with the joined Speed values
        appendDF = appendDF.with_columns(
            pl.when(pl.col('Speed').is_not_null())
            .then(pl.col('Speed'))
            .otherwise(pl.col('Avg_Speed'))
            .alias('Avg_Speed')
        )
        # The first row of each ship has its "Avg_Speed" field set equal to the SOG
        if len(appendDF) > 0:
            # Create a boolean mask for the first row
            first_row_mask = pl.Series([True] + [False] * (len(appendDF) - 1)) # since polars doesn't have indeces, we need to create a mask where the first value is true and all the others are False

            # Update the Avg_Speed for the first row
            appendDF = appendDF.with_columns(
                pl.when(pl.lit(first_row_mask))
                .then(pl.col('SOG'))
                .otherwise(pl.col('Avg_Speed'))
                .alias('Avg_Speed')
            )

        # Any row where avg_speed is null is replaced with the SOG value
        appendDF = appendDF.with_columns(
            pl.when(pl.col('Avg_Speed').is_null())
            .then(pl.col('SOG'))
            .otherwise(pl.col('Avg_Speed'))
            .alias('Avg_Speed')
        )

        # Sometimes a vessel may broadcast an impossible GPS location. This is detected by looking for 
        # absurd values in the freshly calculated 'Avg_Speed' field. Any point that fits this description is then dropped.
        appendDF = appendDF.filter(pl.col('Avg_Speed') < c.ABSURD_SPEED_THRESHOLD)
        appendDF = appendDF.drop('Speed')
        # save the dataframe to the vessels list
        V_s.append(appendDF)

display(V_s[-1].head())
# Out:
# Processing vessels: 100%|██████████| 1954/1954 [00:26<00:00, 73.16it/s]
# shape: (5, 16)
# ┌───────────┬────────────────┬─────────┬────────┬───┬───────┬──────────┬───────────┬───────────────┐
# │ MMSI      ┆ BaseDateTime   ┆ LAT     ┆ LON    ┆ … ┆ Draft ┆ IsClassA ┆ Avg_Speed ┆ EstimatedStat │
# │ ---       ┆ ---            ┆ ---     ┆ ---    ┆   ┆ ---   ┆ ---      ┆ ---       ┆ us            │
# │ i32       ┆ datetime[ms]   ┆ f64     ┆ f64    ┆   ┆ f32   ┆ bool     ┆ f64       ┆ ---           │
# │           ┆                ┆         ┆        ┆   ┆       ┆          ┆           ┆ str           │
# ╞═══════════╪════════════════╪═════════╪════════╪═══╪═══════╪══════════╪═══════════╪═══════════════╡
# │ 912191373 ┆ 2023-05-06     ┆ 57.0581 ┆ 9.8948 ┆ … ┆ 1.3   ┆ true     ┆ 0.0       ┆ null          │
# │           ┆ 00:04:34       ┆         ┆        ┆   ┆       ┆          ┆           ┆               │
# │ 912191373 ┆ 2023-05-06     ┆ 57.058  ┆ 9.8948 ┆ … ┆ 1.3   ┆ true     ┆ 0.12      ┆ null          │
# │           ┆ 00:07:34       ┆         ┆        ┆   ┆       ┆          ┆           ┆               │
# │ 912191373 ┆ 2023-05-06     ┆ 57.058  ┆ 9.8948 ┆ … ┆ 1.3   ┆ true     ┆ 0.0       ┆ null          │
# │           ┆ 00:10:03       ┆         ┆        ┆   ┆       ┆          ┆           ┆               │
# │ 912191373 ┆ 2023-05-06     ┆ 57.0581 ┆ 9.8948 ┆ … ┆ 1.3   ┆ true     ┆ 0.68      ┆ null          │
# │           ┆ 00:10:35       ┆         ┆        ┆   ┆       ┆          ┆           ┆               │
# │ 912191373 ┆ 2023-05-06     ┆ 57.0581 ┆ 9.8948 ┆ … ┆ 1.3   ┆ true     ┆ 0.0       ┆ null          │
# │           ┆ 00:13:36       ┆         ┆        ┆   ┆       ┆          ┆           ┆               │
# └───────────┴────────────────┴─────────┴────────┴───┴───────┴──────────┴───────────┴───────────────┘

# %%
# Function made by ChatGPT

def show_top_memory_vars(limit=5):
    all_vars = {**globals(), **locals()}
    var_sizes = []
    
    for name, obj in all_vars.items():
        if name.startswith('__') or callable(obj) or name == 'all_vars':
            continue
            
        # Gestione specifica per dataframe Polars
        try:
            if hasattr(obj, '__class__') and obj.__class__.__module__ == 'polars.dataframe.frame':
                # Utilizza il metodo estimated_size di Polars per ottenere una stima più accurata
                memory_usage = obj.estimated_size() if hasattr(obj, 'estimated_size') else sys.getsizeof(obj)
                var_sizes.append((name, memory_usage, "polars.DataFrame"))
            else:
                var_sizes.append((name, sys.getsizeof(obj), type(obj).__name__))
        except:
            # Ignora oggetti che causano errori
            pass
    
    for name, size, type_name in sorted(var_sizes, key=lambda x: x[1], reverse=True)[:limit]:
        size_mb = size / (1024 * 1024)  # Conversione a MB per dataframe grandi
        print(f"{name:<15} {size_mb:.2f} MB {type_name}")

# %%
show_top_memory_vars()
# Out:
# clean_df        1033.36 MB polars.DataFrame
# concatDF        798.29 MB polars.DataFrame
# optimized_df    665.96 MB polars.DataFrame
# stationaryDF    317.53 MB polars.DataFrame
# pairsOfPointsDF 0.08 MB polars.DataFrame

# %%
# delete unused dataframe from RAM in order to save memory
# according to StackOverflow, this is the best way: 
# https://stackoverflow.com/questions/64368565/delete-and-release-memory-of-a-single-pandas-dataframe

del clean_df, pairsOfPointsDF, appendDF, speed_values
gc.collect()
# Out:
# 0

# %%
show_top_memory_vars()
# Out:
# concatDF        798.29 MB polars.DataFrame
# optimized_df    665.96 MB polars.DataFrame
# stationaryDF    317.53 MB polars.DataFrame
# shipDF          0.06 MB polars.DataFrame
# filtered_df     0.06 MB polars.DataFrame

# %% [markdown]
# Next part of the TREAD algorithm</br>
#
# Consider as stationary all points where the estimated average speed is lower then a set threshold</br>
# Consider the first (entry) and last (exit) recorded points of each ship as 'stationary', regardless of the estimated speed.</br>
# Set all remaing points as 'sailing'</br>

# %%
# for each vessel (dataframe) in the V_s list,
for index, shipDF in enumerate(V_s):
    # check that the ships are read in the same order
    if shipDF.row(0)[0] != reference_list_of_mmsi[index]:
        print('Error with ships order')
    
    # set the status of each point where the avg_speed is lower than the given threshold to 'stationary'
    shipDF = shipDF.with_columns(
        pl.when((pl.col("Avg_Speed") <= c.SPEED_THRESHOLD) & 
                pl.col('EstimatedStatus').is_null())
          .then(pl.lit('stationary'))
          .otherwise(pl.col('EstimatedStatus'))
          .alias('EstimatedStatus')
    )
    
    # set all remaining null points as "sailing"
    shipDF = shipDF.with_columns(
        pl.when((pl.col("Avg_Speed") > c.SPEED_THRESHOLD) & 
                pl.col('EstimatedStatus').is_null())
          .then(pl.lit('sailing'))
          .otherwise(pl.col('EstimatedStatus'))
          .alias('EstimatedStatus')
    )
    
    # set the first and last points of each ship as "entry" and "exit" points respectively
    first_rows = shipDF.slice(0, 1)
    last_rows = shipDF.slice(shipDF.height - 1, 1)
    
    # Modifica il valore di EstimatedStatus per le prime e ultime righe
    first_rows = first_rows.with_columns(pl.lit('entry').alias('EstimatedStatus'))
    last_rows = last_rows.with_columns(pl.lit('exit').alias('EstimatedStatus'))
    
    # Ricostruisci il DataFrame utilizzando le righe del mezzo (escluse le prime e ultime)
    middle_rows = shipDF.slice(1, shipDF.height - 2)
    shipDF = pl.concat([first_rows, middle_rows, last_rows])
    
    # sometimes a few consecutive points (for the same vessel) might be all with status 'entry' or 'exit'
    # this is unwanted and only one of those points is kept.
    # The rule is: keep the last of any consecutive 'entry' point and keep the first of any consecutive 'exit' point
    tempDF = shipDF.filter((pl.col('EstimatedStatus') == 'entry') | 
                           (pl.col('EstimatedStatus') == 'exit'))
    
    # Aggiungi colonne con il valore precedente e successivo di EstimatedStatus
    tempDF = tempDF.with_columns([
        pl.col('EstimatedStatus').shift(-1).alias('next_status'),
        pl.col('EstimatedStatus').shift(1).alias('prev_status')
    ])
    
    # Identifica le righe da rimuovere
    condition_entry = ((tempDF['EstimatedStatus'] == 'entry') & 
                       (tempDF['next_status'] == 'entry'))
    condition_exit = ((tempDF['EstimatedStatus'] == 'exit') & 
                      (tempDF['prev_status'] == 'exit'))
    
    bad_rows = tempDF.filter(condition_entry | condition_exit)
    
    # if any bad rows exist
    if bad_rows.height > 0:
        # Get the indices to remove
        bad_indices = bad_rows.select(pl.first().struct.field('index')).to_series().to_list()
        print(f'Removed duplicate entry or exit point at index {bad_indices}.')
        print(f'Previous ship len: {shipDF.height}')
        
        # Remove the bad rows
        shipDF = shipDF.filter(~pl.col('index').is_in(bad_indices))
        print(f'Current ship len: {shipDF.height}')
    
    # update the list of vessel with the updated values
    V_s[index] = shipDF

# %%
# print a dataframe and some points just to check the result
filtered_df = V_s[-1]
display(filtered_df.select(["MMSI", "BaseDateTime", "SOG", "Avg_Speed", "EstimatedStatus"]).head(5))

plt.plot(filtered_df.select("Avg_Speed").to_series().to_list())
plt.plot(filtered_df.select("SOG").to_series().to_list())
plt.legend(['Avg_Speed', 'SOG'])
# Out:
# shape: (5, 5)
# ┌───────────┬─────────────────────┬─────┬───────────┬─────────────────┐
# │ MMSI      ┆ BaseDateTime        ┆ SOG ┆ Avg_Speed ┆ EstimatedStatus │
# │ ---       ┆ ---                 ┆ --- ┆ ---       ┆ ---             │
# │ i32       ┆ datetime[ms]        ┆ f64 ┆ f64       ┆ str             │
# ╞═══════════╪═════════════════════╪═════╪═══════════╪═════════════════╡
# │ 912191373 ┆ 2023-05-06 00:04:34 ┆ 0.0 ┆ 0.0       ┆ entry           │
# │ 912191373 ┆ 2023-05-06 00:07:34 ┆ 0.1 ┆ 0.12      ┆ stationary      │
# │ 912191373 ┆ 2023-05-06 00:10:03 ┆ 0.1 ┆ 0.0       ┆ stationary      │
# │ 912191373 ┆ 2023-05-06 00:10:35 ┆ 0.1 ┆ 0.68      ┆ sailing         │
# │ 912191373 ┆ 2023-05-06 00:13:36 ┆ 0.0 ┆ 0.0       ┆ stationary      │
# └───────────┴─────────────────────┴─────┴───────────┴─────────────────┘

# %%
show_top_memory_vars()
# Out:
# concatDF        798.29 MB polars.DataFrame
# optimized_df    665.96 MB polars.DataFrame
# stationaryDF    317.53 MB polars.DataFrame
# shipDF          0.06 MB polars.DataFrame
# filtered_df     0.06 MB polars.DataFrame

# %%
# aggregate all the points back into a single dataframe
concatDF = pl.concat(V_s)
# Extract all the stationary points in a single dataframe
stationaryDF = pl.DataFrame(schema=V_s[0].schema) # new empty df
# stationary points include all points that are useful for extracting routes
stationaryDF = concatDF.filter(
    (pl.col('EstimatedStatus') == 'stationary') |
    (pl.col('EstimatedStatus') == 'entry') |
    (pl.col('EstimatedStatus') == 'exit')
)
print(f'{(stationaryDF.height/optimized_df.height) * 100: .2f}% of points are stationary!')
# Out:
#  38.92% of points are stationary!

# %%
show_top_memory_vars()
# Out:
# concatDF        798.29 MB polars.DataFrame
# optimized_df    665.96 MB polars.DataFrame
# stationaryDF    317.53 MB polars.DataFrame
# shipDF          0.06 MB polars.DataFrame
# filtered_df     0.06 MB polars.DataFrame

# %%
# Some computationl tricks in order to save some time
print(f'Currently there are {stationaryDF.height} stationary points!')
# Group-by same (lat,lon) pairs and count occurrencies
groupedDF = (stationaryDF
    .group_by(['LAT', 'LON'])
    .agg(pl.len().alias('Weight'))
)
print(f'The new df has {groupedDF.height} rows!')

# Find the index of the maximum value before applying the logarithm
max_weight_row = groupedDF.filter(pl.col('Weight') == pl.col('Weight').max()).row(0)
print("Pair with most occurrencies: \n" + str(max_weight_row) + '\n')

# Apply log2() (base-2 logarithm) to the 'weight' column in order to rescale its values
groupedDF = groupedDF.with_columns(
    pl.col('Weight')
    .map_elements(lambda x: np.round(np.log2(x), decimals=0), return_dtype=pl.Float64)
    .alias('Weight')
)
# The minimum weight should be 1, so any zero is arbitrarly replaced with 1.
groupedDF = groupedDF.with_columns(
    pl.when(pl.col('Weight') == 0)
    .then(1)
    .otherwise(pl.col('Weight'))
    .alias('Weight')
)
display(pl.concat([groupedDF.sort(by='Weight', descending=True).head(50), groupedDF.tail(5)]))

# To find the same LAT,LON pair after the transformation, use the saved values
lat_value, lon_value = max_weight_row[0], max_weight_row[1]
max_pair_after_transform = groupedDF.filter(
    (pl.col('LAT') == lat_value) & (pl.col('LON') == lon_value)
).row(0)
print("Pair with most occurrencies: \n" + str(max_pair_after_transform) + '\n')
# Out:
# Currently there are 3421702 stationary points!
# The new df has 311572 rows!
# Pair with most occurrencies:
# (57.7152, 10.5842, 10025)
# shape: (55, 3)
# ┌─────────┬─────────┬────────┐
# │ LAT     ┆ LON     ┆ Weight │
# │ ---     ┆ ---     ┆ ---    │
# │ f64     ┆ f64     ┆ f64    │
# ╞═════════╪═════════╪════════╡
# │ 55.0588 ┆ 10.6193 ┆ 13.0   │
# │ 57.0582 ┆ 9.9008  ┆ 13.0   │
# │ 57.5934 ┆ 9.9621  ┆ 13.0   │
# │ 55.6136 ┆ 12.9977 ┆ 13.0   │
# │ 54.9335 ┆ 10.8334 ┆ 13.0   │
# │ …       ┆ …       ┆ …      │
# │ 57.0551 ┆ 8.0247  ┆ 1.0    │
# │ 56.7006 ┆ 8.2485  ┆ 1.0    │
# │ 57.6667 ┆ 10.7401 ┆ 2.0    │
# │ 56.3564 ┆ 7.0051  ┆ 1.0    │
# │ 55.6609 ┆ 10.1584 ┆ 1.0    │
# └─────────┴─────────┴────────┘
# Pair with most occurrencies:
# (57.7152, 10.5842, 13.0)

# %%
show_top_memory_vars()
# Out:
# concatDF        798.29 MB polars.DataFrame
# optimized_df    665.96 MB polars.DataFrame
# stationaryDF    317.53 MB polars.DataFrame
# groupedDF       7.13 MB polars.DataFrame
# shipDF          0.06 MB polars.DataFrame

# %%
del optimized_df
gc.collect()

# %%
# Run DBSCAN algorithm on the grouped stationary points
# this scatter plot gives a rough idea of how the points should look like plotted on a map
plt.scatter(groupedDF.select('LON').to_numpy(), groupedDF.select('LAT').to_numpy(), s=0.01)
# inizitalize dbscan object with parameters. TODO: test multiple parameters combinations
dbscan = DBSCAN(eps=0.075, min_samples=10)
estimator = dbscan.fit(
    X=groupedDF.select(['LAT', 'LON']).to_numpy(),
    sample_weight=groupedDF.select('Weight').to_numpy().flatten()
)
print(str(estimator) + " len: " + str(len(estimator.labels_)) + ", num of clusters: " + str(max(estimator.labels_)))
# Add labels to the dataframe
groupedDF = groupedDF.with_columns(pl.Series(name='Label', values=estimator.labels_))
display(pl.concat([groupedDF.sort(by='Weight', descending=True).head(50), groupedDF.tail(5)]))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# plot the result of the DBSCAN clustering on a map (to have a look at the effects of the parameters)

clusteredPointsDF = groupedDF[groupedDF['Label'] != -1].copy()
outliersDF = groupedDF[groupedDF['Label'] == -1].copy()
clusteredPointsDF.reset_index(inplace=True)
outliersDF.reset_index(inplace=True)

display(p.concat([clusteredPointsDF.head(5), clusteredPointsDF.tail(5)]))

f.points_plotter(clustered=clusteredPointsDF,
               not_clustered=outliersDF,
               model=estimator)
# Out:
#        index      LAT       LON  Weight  Label
# 0          0  18.7665 -155.7773     1.0      1
# 1         12  18.7673 -155.9327     1.0      1
# 2         16  18.7677 -155.7892     1.0      1
# 3         17  18.7680 -158.2825     1.0      0
# 4         19  18.7682 -155.9034     1.0      1
# 53274  54335  22.6305 -155.5342     1.0     56
# 53275  54340  22.6307 -156.3146     1.0     54
# 53276  54342  22.6308 -156.8662     1.0     51
# 53277  54343  22.6308 -155.5218     1.0     56
# 53278  54344  22.6309 -158.3782     1.0     55

# %% [markdown]
# #### Hierarchical DBSCAN
#
# Since the current sklearn hdbscan implementation does not allow to pass the weights of points as input,
# the DataFrame that stores stationary points needs a little change: instead of passing the weights for each
# coordinate, each line representing a coordinate is going to be duplicated for the same amount specified by its own weight

# %%
print(f'The new DF should have about {groupedDF.shape[0]} * {groupedDF["Weight"].mean(), 3} = {groupedDF.shape[0] * groupedDF["Weight"].mean()} rows.')

repeated_indices = np.repeat(groupedDF.index, groupedDF['Weight'])

h_groupedDF = groupedDF.loc[repeated_indices, ['LAT', 'LON']].reset_index(drop=True)

print('Rows of the new DF: {}'.format(h_groupedDF.shape[0]))

print(f'The new DF, if a "groupby" is applied again, should have the same number of rows of the original: {groupedDF.shape[0]} = {h_groupedDF.value_counts().shape[0]}')
# Out:
# The new DF should have about 54345 * (1.8471248504922255, 3) = 100382.0 rows.
# Rows of the new DF: 100382
# The new DF, if a "groupby" is applied again, should have the same number of rows of the original: 54345 = 54345

# %%
# Run H-DBSCAN algorithm on the stationary points

# inizitalize h-dbscan object with parameters. TODO: test multiple parameters combinations
h_dbscan = hdbs.HDBSCAN(min_cluster_size=30,
                        cluster_selection_epsilon=0.01,
                        max_cluster_size=10_000)

h_labels = h_dbscan.fit_predict(
                    X=h_groupedDF.loc[:, ['LAT','LON']]
                    )

print(str(h_dbscan) + " len: " + str(len(h_labels)) + ", num of clusters: " + str(max(h_labels)))

# Add labels to the dataframe
h_groupedDF['Label'] = h_labels

display(h_groupedDF)
#print(groupedDF['Label'].max())
# Out:
# HDBSCAN(cluster_selection_epsilon=0.01, max_cluster_size=10000,
#         min_cluster_size=30) len: 100382, num of clusters: 152
#             LAT       LON  Label
# 0       18.7665 -155.7773     -1
# 1       18.7666 -156.9702     -1
# 2       18.7667 -156.8071     -1
# 3       18.7669 -156.6011     -1
# 4       18.7669 -156.5696     -1
# ...         ...       ...    ...
# 100377  22.6307 -156.3146      0
# 100378  22.6308 -158.4875     -1
# 100379  22.6308 -156.8662      0
# 100380  22.6308 -155.5218      1
# 100381  22.6309 -158.3782     -1
#
# [100382 rows x 3 columns]

# %%
# Show the result of h-dbscan on a map

clusteredPointsDF = h_groupedDF[(h_groupedDF['Label'] != -1)].copy()
outliersDF = h_groupedDF[h_groupedDF['Label'] == -1].copy()

clusteredPointsDF = clusteredPointsDF.groupby(by=['LAT', 'LON', 'Label']).size().reset_index(name='Weight')

# plot points and clusters
f.points_plotter(clustered=clusteredPointsDF,
               not_clustered=outliersDF,
               model=h_dbscan)

# %% [markdown]
# Plot a heatmap using all the points, even the non-stationary ones

# %%
# %%script false --no-raise-error
# # the code above is used to prevent the Python kernel from running this cell (https://stackoverflow.com/a/56247673/24805169)
#
# concatDF[['LAT','LON']] = concatDF[['LAT','LON']].round(3)
#
# heatmapDF = concatDF.groupby(['LAT','LON']).size().reset_index(name='Weight')
#
# # Apply log2() (base-2 logarithm) to the 'weight' column in order to rescale its values
# heatmapDF['Weight'] = np.round(
#                                 np.log2(heatmapDF['Weight']),
#                                 decimals=0
#                             )
# # The minimum weight should be 1, so any zero is replaced
# #heatmapDF['Weight'].replace(0,1,inplace=True)
#
# print("Pair with most occurrencies: \n" + str(heatmapDF.iloc[heatmapDF['Weight'].idxmax(), :]) + '\n')
# print(concatDF.shape)
# print(heatmapDF.shape)

# %%
# %%script false --no-raise-error
# # the code above is used to prevent the Python kernel from running this cell (https://stackoverflow.com/a/56247673/24805169)
#
# fig2 = px.density_mapbox(
#     data_frame=heatmapDF,
#     lat='LAT',
#     lon='LON',
#     z='Weight',
#     radius=5,
#     zoom=6,
#     mapbox_style='open-street-map'
# )
# fig2.update_layout(mapbox_style = 'open-street-map',
#                     margin={'r':0, 't':40, 'l':0, 'b':0}
#                     )
#
# po.plot(fig2)

# %% [markdown]
# ### Waypoints and Routes identification</br>
#
# ##### Waypoints

# %%
num_of_wp = h_groupedDF['Label'].max()

# Creation of a df for storing the Waypoints
waypointsDF = p.DataFrame()
waypointsDF['Name'] = ['WP_' + str(i) for i in range(0, num_of_wp+1)] # every WP is named 'WP_X', where X is a integer value
waypointsDF['ConvexHullObj'] = p.Series()  # empty column
waypointsDF['VerticesIndex'] = p.Series() # empty column
waypointsDF['LAT'] = p.Series() # empty column
waypointsDF['LON'] = p.Series() # empty column
waypointsDF['Coords'] = p.Series() # empty column
waypointsDF['PolygonObj'] = p.Series() # empty column
# Exclude non-clustered (noise) points (labeled as -1)
onlyClusteredPointsDF = h_groupedDF[h_groupedDF['Label'] != -1].copy()


for wp_label in onlyClusteredPointsDF['Label'].unique():
    # create convex hull object using all points with label = wp_label (concave hulls/ alpha shapes could be an alternative but they require an additional parameter))
    groupLATLONDF = onlyClusteredPointsDF[onlyClusteredPointsDF['Label']==wp_label][['LAT', 'LON']]
    conv_hull = ConvexHull(groupLATLONDF)
    # store the ConvexHull object in the dataframe
    waypointsDF.loc[wp_label, 'ConvexHullObj'] = conv_hull
    # and also store the vertices of the ConvexHull (waypoint)
    waypointsDF.at[wp_label, 'VerticesIndex'] = conv_hull.vertices
    
    # this list comprehension creates a list of series
    hull_lon = [groupLATLONDF['LON'].reset_index().iloc[vertex_idx] for vertex_idx in conv_hull.vertices]
    hull_lat = [groupLATLONDF['LAT'].reset_index().iloc[vertex_idx] for vertex_idx in conv_hull.vertices]
    
    #from the list of series extract the second value of each serie (after converting the serie to list)
    hull_lon = [serie.tolist()[1] for serie in hull_lon]
    hull_lat = [serie.tolist()[1] for serie in hull_lat]

    # save the LAT and LON values to the appropriate row and column
    waypointsDF.at[wp_label, 'LAT'] = hull_lat
    waypointsDF.at[wp_label, 'LON'] = hull_lon

    # zip the LAT and LON values of each row together in a new column (this is needed in order to create a Polygon)
    waypointsDF.at[wp_label, 'Coords'] = list(zip(hull_lon, hull_lat))
    waypointsDF.at[wp_label, 'Coords'].append((hull_lon[0], hull_lat[0]))

    # create a Polygon
    waypointsDF.at[wp_label, 'PolygonObj'] = Polygon(waypointsDF.at[wp_label, 'Coords'])


display(waypointsDF.head())
# Out:
#    Name                                      ConvexHullObj  \
# 0  WP_0  <scipy.spatial._qhull.ConvexHull object at 0x7...
# 1  WP_1  <scipy.spatial._qhull.ConvexHull object at 0x7...
# 2  WP_2  <scipy.spatial._qhull.ConvexHull object at 0x7...
# 3  WP_3  <scipy.spatial._qhull.ConvexHull object at 0x7...
# 4  WP_4  <scipy.spatial._qhull.ConvexHull object at 0x7...
#
#                                       VerticesIndex  \
# 0  [10, 0, 1, 4, 5, 57, 90, 92, 91, 89, 79, 51, 35]
# 1                     [2, 0, 3, 12, 33, 35, 28, 15]
# 2                      [0, 6, 42, 45, 43, 30, 2, 1]
# 3                                 [0, 119, 120, 96]
# 4      [21, 15, 7, 1, 0, 25, 90, 108, 132, 147, 82]
#
#                                                  LAT  \
# 0  [22.4381, 22.3165, 22.3427, 22.3684, 22.4072, ...
# 1  [22.5747, 22.3764, 22.5822, 22.6237, 22.6305, ...
# 2  [22.2183, 22.3573, 22.5369, 22.5887, 22.5532, ...
# 3                [19.341, 19.6974, 19.7057, 19.5716]
# 4  [19.7993, 19.7948, 19.7895, 19.7861, 19.7852, ...
#
#                                                  LON  \
# 0  [-156.1624, -156.5759, -156.8063, -156.8505, -...
# 1  [-155.4326, -155.3154, -155.6414, -155.6922, -...
# 2  [-155.1645, -155.2647, -155.1897, -154.95, -15...
# 3       [-156.4086, -156.6439, -156.5188, -156.4468]
# 4  [-155.0228, -155.0233, -155.0335, -155.0423, -...
#
#                                               Coords  \
# 0  [(-156.1624, 22.4381), (-156.5759, 22.3165), (...
# 1  [(-155.4326, 22.5747), (-155.3154, 22.3764), (...
# 2  [(-155.1645, 22.2183), (-155.2647, 22.3573), (...
# 3  [(-156.4086, 19.341), (-156.6439, 19.6974), (-...
# 4  [(-155.0228, 19.7993), (-155.0233, 19.7948), (...
#
#                                           PolygonObj
# 0  POLYGON ((-156.1624 22.4381, -156.5759 22.3165...
# 1  POLYGON ((-155.4326 22.5747, -155.3154 22.3764...
# 2  POLYGON ((-155.1645 22.2183, -155.2647 22.3573...
# 3  POLYGON ((-156.4086 19.341, -156.6439 19.6974,...
# 4  POLYGON ((-155.0228 19.7993, -155.0233 19.7948...

# %%
# quick plot the extracted polygons to check if everything worked fine
import geopandas
quick_plot = geopandas.GeoSeries(waypointsDF['PolygonObj'])
quick_plot.plot()
# Out:
# <Axes: >

# %% [markdown]
# ##### Routes identification

# %%
# for each LAT, LON pair, create a shapely.Point
concatDF['PointsObj'] = [shpl.Point(x,y) for (x,y) in concatDF[['LON', 'LAT']].values] #apparently this is faster than usig pandas.Dataframe.apply()

# for each WP, for each row of the entire dataset, check if the point is inside any WP
for name, polygon_obj in  waypointsDF[['Name', 'PolygonObj']].values:
    concatDF[str(name)] = polygon_obj.contains(concatDF['PointsObj']) # for each wp, create a new column containing either True or False

# list of column names just created
list_of_columns = [name for name in waypointsDF['Name']]

#idxmax: for each row, return the id (name) of the column containing the first occurrence of the maximum value. There are only bool values so True = 1 > False = 0
# basically returns the name of the WP where the point is contained. If the row has only 'False' values, it returns the first column (this is fixed below)
# this works under the assumption that any given point can belong to either zero or one WP.
concatDF['IsInWP'] = concatDF[list_of_columns].idxmax(axis=1)

# find all rows that have only 'False' values. The '~' negates the values (its like applying the binary NOT)
all_false_rows = concatDF[(~concatDF[list_of_columns]).all(axis=1)].index
# Replace the value in the 'IsInWP' column as 'None'
concatDF.loc[all_false_rows, 'IsInWP'] = None
# drop unnecessary columns
concatDF.drop(list_of_columns, axis=1, inplace=True)
concatDF.drop(['index', 'PointsObj'], axis=1, inplace=True)

display(concatDF.head(10))
# Out:
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_17739/3323970853.py:14: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#      MMSI        BaseDateTime      LAT       LON  SOG    COG  Heading  \
# 0  382872 2019-01-08 19:32:26  21.3557 -157.9487  5.1  308.0    511.0
# 1  382872 2019-01-08 19:33:37  21.3569 -157.9501  5.2  316.5    511.0
# 2  382872 2019-01-08 19:34:47  21.3580 -157.9514  5.2  300.0    511.0
# 3  382872 2019-01-08 19:35:57  21.3584 -157.9532  5.2  274.0    511.0
# 4  382872 2019-01-08 19:37:07  21.3578 -157.9548  5.1  232.0    511.0
# 5  382872 2019-01-08 19:38:24  21.3571 -157.9565  5.2  247.7    511.0
# 6  382872 2019-01-08 19:39:42  21.3563 -157.9584  5.2  242.2    511.0
# 7  382872 2019-01-08 19:41:03  21.3555 -157.9603  5.2  246.0    511.0
# 8  382872 2019-01-08 19:42:13  21.3550 -157.9621  5.2  258.4    511.0
# 9  382872 2019-01-08 19:43:24  21.3546 -157.9638  5.2  257.9    511.0
#
#   VesselName  VesselType  Status  Length  Width  Draft  IsClassA  Avg_Speed  \
# 0    HARRIER           0      15      20      5    0.0      True       5.10
# 1    HARRIER           0      15      20      5    0.0      True       5.40
# 2    HARRIER           0      15      20      5    0.0      True       5.06
# 3    HARRIER           0      15      20      5    0.0      True       5.33
# 4    HARRIER           0      15      20      5    0.0      True       4.97
# 5    HARRIER           0      15      20      5    0.0      True       4.86
# 6    HARRIER           0      15      20      5    0.0      True       5.39
# 7    HARRIER           0      15      20      5    0.0      True       5.19
# 8    HARRIER           0      15      20      5    0.0      True       5.41
# 9    HARRIER           0      15      20      5    0.0      True       4.98
#
#   EstimatedStatus  IsInWP
# 0           entry  WP_149
# 1         sailing  WP_149
# 2         sailing  WP_149
# 3         sailing  WP_149
# 4         sailing  WP_149
# 5         sailing  WP_149
# 6         sailing  WP_149
# 7         sailing  WP_149
# 8         sailing  WP_149
# 9         sailing  WP_149

# %%
# count the number of points contained in each WP. 
# 'WP_X' -> the point is generated inside WP_X
# None -> the point does not belong to any cluster
value_counts = concatDF['IsInWP'].value_counts(dropna=False)
print(value_counts)
print(concatDF.shape)
# quick plot of the WP with the highest amount of points
testDF = concatDF[concatDF['IsInWP'] == value_counts.index[0]]
plt.scatter(testDF['LON'], testDF['LAT'], s=0.01)
# Out:
# IsInWP
# WP_152    2925926
# None      1278799
# WP_120     356533
# WP_149     349206
# WP_35       86235
#            ...
# WP_71          50
# WP_14          50
# WP_10          47
# WP_28          40
# WP_142         39
# Name: count, Length: 154, dtype: int64
# (5460741, 17)

# %% [markdown]
# #### Routes extraction
# For each vessel contained in V_s (used at the beginning of this notebook), create a new column (called 'Route') specifying the current route.</br>If the ship is inside a WP, than the WP name is used in the new column.</br>If the ship is at open sea ('IsInWP' == None) then the Route column is filled in the following way:
# * let A and B be the names of the start and end WPs, respectively. In order for them to be considered, they need to be either 'entry' or 'exit' WPs, or the vessel needs to generate at least one stationary point inside them
# * if both A and B are known, the route name is built as A - B
# * if either one is missing (pd.NA), the route name is built as "\<NA> - B" or "A - \<NA>"

# %%
concatDF['IsInSignificantWP'] = p.Series(dtype=p.StringDtype())
concatDF['Route'] = p.Series(dtype=p.StringDtype())
print(concatDF.shape)
for index, unique_mmsi in enumerate(reference_list_of_mmsi):
    vesselDF = concatDF[concatDF['MMSI'] == unique_mmsi].copy().reset_index(drop=True)
    vesselDF['IsInSignificantWP'] = p.Series(dtype=p.StringDtype()) # new empty column
    vesselDF['PreviousWP'] = p.Series(dtype=p.StringDtype())
    vesselDF['NextWP'] = p.Series(dtype=p.StringDtype())
    # extract the indeces of any entry-exit pair of points
    entry_points_index = vesselDF[vesselDF['EstimatedStatus'] == 'entry'].index.to_list()
    exit_points_index = vesselDF[vesselDF['EstimatedStatus'] == 'exit'].index.to_list()
    entry_exit_pairs_list = list(zip(entry_points_index, exit_points_index))
    # check formal validity of entry/exit pairs
    for idx, pair in enumerate(entry_exit_pairs_list):
        entry_idx, exit_idx = pair[0], pair[1]
        sub_range = range(entry_idx, exit_idx+1)            
        next_item = entry_exit_pairs_list[(idx + 1) % len(entry_exit_pairs_list)]
        if ((exit_idx + 1) != next_item[0]) and (idx+1 != len(entry_exit_pairs_list)):
            print(f'Error for tuples {pair}, {next_item} for vessel {unique_mmsi} with index {index}')
            break
        # if the pair is valid, extract the routes

        # create a new column for storing when a point is in a WP with a Avg_Speed lower than the threshold used for stationary points
        significantWP_condition = ( (vesselDF.loc[sub_range, 'Avg_Speed'] <= c.SPEED_THRESHOLD)
                                    | (vesselDF.loc[sub_range, 'EstimatedStatus'] == 'entry')
                                    | (vesselDF.loc[sub_range, 'EstimatedStatus'] == 'exit') 
                                   )

        vesselDF.loc[sub_range, 'IsInSignificantWP'] = np.where(significantWP_condition, vesselDF.loc[sub_range, 'IsInWP'], None)
  
        # create a new column where each row contains the name of the previous WP
        vesselDF.loc[sub_range, 'PreviousWP'] = vesselDF.loc[sub_range, 'IsInSignificantWP'].ffill()
        
        # create a new column where each row contains the name of the following WP
        vesselDF.loc[sub_range, 'NextWP'] = vesselDF.loc[sub_range, 'IsInSignificantWP'].bfill()
    
        #replace None values with pandas.NA, which is like np.NaN but for non-numeric values
        vesselDF.loc[sub_range, 'PreviousWP'] = vesselDF.loc[sub_range, 'PreviousWP'].fillna(p.NA)
        vesselDF.loc[sub_range, 'NextWP'] = vesselDF.loc[sub_range, 'NextWP'].fillna(p.NA)
        
        # create the route name as 'A - B'
        vesselDF.loc[sub_range, 'Route'] = vesselDF.loc[sub_range, 'IsInSignificantWP'].combine_first(vesselDF.loc[sub_range, 'PreviousWP'].astype(str) + ' - ' + vesselDF.loc[sub_range, 'NextWP'].astype(str))

    # remove auxiliary columns that aren't necessary anymore
    vesselDF.drop(['PreviousWP', 'NextWP'], axis=1, inplace=True)
    #save df to the list of vessels (V_s)
    V_s[index] = vesselDF.copy()

concatDF = p.concat(V_s).copy()
#print(V_s[200][['BaseDateTime', 'MMSI', 'LAT', 'LON', 'EstimatedStatus', 'Avg_Speed', 'IsInWP','IsInSignificantWP', 'Route']].to_string())
display(V_s[0].loc[0:100])
# Out:
# (5460741, 19)
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# ...
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#
# /tmp/ipykernel_17739/3347029058.py:42: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#        MMSI        BaseDateTime      LAT       LON  SOG    COG  Heading  \
# 0    382872 2019-01-08 19:32:26  21.3557 -157.9487  5.1  308.0    511.0
# 1    382872 2019-01-08 19:33:37  21.3569 -157.9501  5.2  316.5    511.0
# 2    382872 2019-01-08 19:34:47  21.3580 -157.9514  5.2  300.0    511.0
# 3    382872 2019-01-08 19:35:57  21.3584 -157.9532  5.2  274.0    511.0
# 4    382872 2019-01-08 19:37:07  21.3578 -157.9548  5.1  232.0    511.0
# ..      ...                 ...      ...       ...  ...    ...      ...
# 96   382872 2019-01-08 21:25:36  21.3532 -157.9402  0.0   93.3    511.0
# 97   382872 2019-01-08 21:26:46  21.3532 -157.9402  0.0   88.1    511.0
# 98   382872 2019-01-08 21:27:56  21.3532 -157.9402  0.0   82.7    511.0
# 99   382872 2019-01-08 21:29:07  21.3531 -157.9402  0.0    0.0    511.0
# 100  382872 2019-01-08 21:30:37  21.3531 -157.9402  0.0   86.8    511.0
#
#     VesselName  VesselType  Status  Length  Width  Draft  IsClassA  Avg_Speed  \
# 0      HARRIER           0      15      20      5    0.0      True       5.10
# 1      HARRIER           0      15      20      5    0.0      True       5.40
# 2      HARRIER           0      15      20      5    0.0      True       5.06
# 3      HARRIER           0      15      20      5    0.0      True       5.33
# 4      HARRIER           0      15      20      5    0.0      True       4.97
# ..         ...         ...     ...     ...    ...    ...       ...        ...
# 96     HARRIER           0      15      20      5    0.0      True       0.00
# 97     HARRIER           0      15      20      5    0.0      True       0.00
# 98     HARRIER           0      15      20      5    0.0      True       0.00
# 99     HARRIER           0      15      20      5    0.0      True       0.30
# 100    HARRIER           0      15      20      5    0.0      True       0.00
#
#     EstimatedStatus  IsInWP IsInSignificantWP            Route
# 0             entry  WP_149            WP_149           WP_149
# 1           sailing  WP_149              <NA>  WP_149 - WP_149
# 2           sailing  WP_149              <NA>  WP_149 - WP_149
# 3           sailing  WP_149              <NA>  WP_149 - WP_149
# 4           sailing  WP_149              <NA>  WP_149 - WP_149
# ..              ...     ...               ...              ...
# 96       stationary    None              <NA>  WP_149 - WP_149
# 97       stationary    None              <NA>  WP_149 - WP_149
# 98       stationary    None              <NA>  WP_149 - WP_149
# 99       stationary    None              <NA>  WP_149 - WP_149
# 100      stationary    None              <NA>  WP_149 - WP_149
#
# [101 rows x 19 columns]

# %% [markdown]
# ##### Plot ship path on a map

# %%
# dataframe structure should be the same of "concatDF"
to_be_plotted = V_s[0]
f.plot_routes(to_be_plotted, clusteredPointsDF, "SingleVessel")

# %% [markdown]
# #### Search for the most popular routes

# %%
def count_groups(df, col_name):
    df['shifted'] = df[col_name].shift(1)
    df['change'] = df[col_name] != df['shifted']
    df['group'] = df['change'].cumsum()
    group_counts = df.groupby('group')[col_name].first().value_counts()
    return group_counts

result = {}

for temp_vessel in V_s:
    group_counts = count_groups(temp_vessel, 'Route')
    for key, count in group_counts.items():
        if key not in result.keys():
            result[key] = count
        else:
            result[key] += count

tempDF = p.DataFrame(data={'Name': result.keys(), 'Count': result.values()}).sort_values(by='Count', ascending=False).to_string()
print(tempDF)
# Out:
#                 Name  Count
# 4             WP_152  18683
# 5    WP_152 - WP_152  17262
# 0             WP_149   7576
# 1    WP_149 - WP_149   7446
# 760           WP_131   2928
# 761  WP_131 - WP_131   2926
# 76            WP_136   2183
# 73            WP_120   2042
# 77   WP_136 - WP_136   2030
# 43             WP_96   1982
# 82   WP_120 - WP_120   1703
# 98     WP_96 - WP_96   1615
# 93             WP_35   1226
# 83             WP_11   1143
# 129    WP_35 - WP_35   1055
# 84     WP_11 - WP_11   1017
# 35             WP_80    700
# 80     WP_80 - WP_80    560
# 33             WP_30    526
# 8      WP_152 - <NA>    438
# 41     WP_30 - WP_30    429
# 11     <NA> - WP_152    424
# 32             WP_61    409
# 56             WP_66    341
# 71             WP_77    325
# 165           WP_146    299
# 247    WP_61 - WP_96    287
# 46     WP_96 - WP_61    286
# 104           WP_133    284
# 166  WP_146 - WP_146    280
# 106  WP_133 - WP_133    274
# 605            WP_94    274
# 58     WP_66 - WP_66    237
# 265    WP_77 - WP_77    201
# 606    WP_94 - WP_94    194
# 90   WP_152 - WP_120    187
# 235  WP_120 - WP_152    164
# 728            WP_34    154
# 729    WP_34 - WP_34    152
# 54             WP_46    148
# 51             WP_90    142
# 290            WP_93    134
# 291    WP_93 - WP_93    129
# 221   WP_152 - WP_35    120
# 156  WP_136 - WP_152    115
# 78   WP_152 - WP_136    114
# 211            WP_73    111
# 37             WP_74    110
# 413            WP_53    106
# 47     WP_61 - WP_61    106
# 122           WP_126    105
# 502            WP_72    104
# 189           WP_148    102
# 91    WP_35 - WP_152    102
# 55     WP_46 - WP_46    101
# 123  WP_126 - WP_126    100
# 190  WP_148 - WP_148     85
# 417    WP_53 - WP_53     82
# 86              WP_4     81
# 27       <NA> - <NA>     81
# 94    WP_11 - WP_152     81
# 626           WP_143     78
# 85    WP_152 - WP_11     77
# 628  WP_143 - WP_143     75
# 828            WP_85     75
# 730            WP_33     75
# 829    WP_85 - WP_85     74
# 731    WP_33 - WP_33     74
# 322            WP_86     72
# 318            WP_87     71
# 593            WP_76     68
# 331    WP_90 - WP_90     59
# 612    WP_77 - WP_90     59
# 314   WP_30 - WP_152     58
# 452    WP_66 - WP_77     58
# 607    WP_94 - WP_77     58
# 334    WP_74 - WP_74     58
# 830           WP_105     57
# 315   WP_152 - WP_30     57
# 588             WP_3     57
# 201            WP_49     56
# 669    WP_90 - WP_66     55
# 831  WP_105 - WP_105     55
# 202    WP_49 - WP_49     54
# 589      WP_3 - WP_3     53
# 313   WP_73 - WP_152     53
# 732            WP_69     52
# 519    WP_80 - WP_72     52
# 248           WP_106     52
# 319    WP_87 - WP_87     51
# 733    WP_69 - WP_69     51
# 455           WP_144     50
# 329            WP_67     50
# 256           WP_129     49
# 7               WP_0     49
# 6               WP_8     48
# 608    WP_77 - WP_94     47
# 312   WP_152 - WP_73     47
# 853  WP_144 - WP_144     46
# 525    WP_72 - WP_80     46
# 498            WP_37     46
# 151           WP_141     46
# 464            WP_13     46
# 705           WP_125     45
# 255  WP_129 - WP_129     44
# 594    WP_76 - WP_76     43
# 152  WP_141 - WP_141     43
# 493            WP_63     43
# 279           WP_134     42
# 257            WP_88     42
# 706  WP_125 - WP_125     42
# 882            WP_25     40
# 177           WP_139     40
# 280  WP_134 - WP_134     40
# 183           WP_118     39
# 499            WP_45     39
# 883    WP_25 - WP_25     38
# 178  WP_139 - WP_139     38
# 66              WP_5     38
# 184  WP_118 - WP_118     37
# 512    WP_72 - WP_72     37
# 304           WP_115     37
# 846           WP_138     36
# 501            WP_44     36
# 500            WP_48     36
# 187            WP_70     36
# 483            WP_15     36
# 250  WP_106 - WP_106     36
# 305  WP_115 - WP_115     35
# 14             WP_24     35
# 847  WP_138 - WP_138     35
# 484    WP_15 - WP_15     35
# 67       WP_5 - WP_5     34
# 330    WP_86 - WP_86     34
# 767           WP_102     33
# 782            WP_99     33
# 15     WP_24 - WP_24     32
# 26             WP_16     32
# 844    WP_73 - WP_73     32
# 320            WP_95     32
# 503    WP_45 - WP_45     32
# 2      <NA> - WP_149     32
# 713            WP_12     32
# 780           WP_101     32
# 89     WP_4 - WP_152     32
# 768  WP_102 - WP_102     31
# 504    WP_44 - WP_44     31
# 783    WP_99 - WP_99     31
# 714    WP_12 - WP_12     30
# 277             WP_2     30
# 268   WP_46 - WP_152     30
# 103           WP_127     29
# 333    WP_67 - WP_67     29
# 28             WP_31     29
# 791             WP_7     29
# 3      WP_149 - <NA>     29
# 781  WP_101 - WP_101     29
# 105  WP_127 - WP_127     28
# 16             WP_23     28
# 715            WP_52     28
# 188    WP_70 - WP_70     28
# 321            WP_47     28
# 75     WP_120 - <NA>     28
# 9      WP_8 - WP_152     28
# 284           WP_123     28
# 789             WP_6     27
# 36     WP_80 - WP_74     27
# 29     WP_31 - WP_31     27
# 716    WP_52 - WP_52     27
# 559    WP_96 - WP_86     27
# 323            WP_32     27
# 95     WP_152 - WP_4     27
# 182    WP_2 - WP_152     27
# 505            WP_43     27
# 261            WP_89     27
# 185            WP_81     27
# 13     WP_152 - WP_8     26
# 231           WP_121     26
# 107            WP_92     26
# 609    WP_63 - WP_63     26
# 324    WP_47 - WP_47     26
# 400             WP_1     25
# 412   WP_35 - WP_120     25
# 560    WP_86 - WP_96     25
# 238           WP_116     25
# 167           WP_145     25
# 20     WP_23 - WP_23     25
# 108    WP_92 - WP_92     25
# 824            WP_97     25
# 74     <NA> - WP_120     24
# 507    WP_37 - WP_37     24
# 790      WP_6 - WP_6     24
# 414   WP_120 - WP_35     24
# 506            WP_42     24
# 825    WP_97 - WP_97     24
# 508            WP_54     23
# 524            WP_75     23
# 447  WP_120 - WP_136     23
# 17             WP_19     23
# 325            WP_68     23
# 798      WP_7 - WP_7     23
# 734            WP_41     23
# 326    WP_95 - WP_95     23
# 127            WP_91     23
# 819           WP_110     23
# 168  WP_145 - WP_145     22
# 735    WP_41 - WP_41     22
# 327    WP_32 - WP_32     22
# 128           WP_130     22
# 694           WP_119     22
# 224            WP_60     22
# 109             WP_9     22
# 736            WP_22     22
# 769            WP_27     22
# 288  WP_123 - WP_123     22
# 467    WP_13 - WP_13     22
# 22     WP_19 - WP_19     21
# 12     WP_152 - WP_0     21
# 799            WP_83     21
# 820  WP_110 - WP_110     21
# 770    WP_27 - WP_27     21
# 509    WP_48 - WP_48     21
# 737    WP_22 - WP_22     21
# 203            WP_50     21
# 130    WP_91 - WP_91     21
# 169           WP_137     20
# 110      WP_9 - WP_9     20
# 771           WP_128     20
# 225    WP_60 - WP_60     20
# 695  WP_119 - WP_119     20
# 800    WP_83 - WP_83     20
# 258    WP_88 - WP_88     19
# 239  WP_116 - WP_116     19
# 131  WP_130 - WP_130     19
# 328    WP_68 - WP_68     19
# 204    WP_50 - WP_50     19
# 186    WP_81 - WP_81     19
# 426   WP_152 - WP_53     19
# 372    WP_74 - WP_80     19
# 170  WP_137 - WP_137     19
# 25    WP_152 - WP_16     18
# 711   WP_149 - WP_30     18
# 772  WP_128 - WP_128     18
# 712   WP_30 - WP_149     18
# 49             WP_36     18
# 111            WP_82     18
# 738           WP_103     17
# 316     WP_35 - WP_4     17
# 399    WP_152 - WP_1     17
# 87    WP_120 - WP_11     17
# 112    WP_82 - WP_82     17
# 232  WP_121 - WP_121     16
# 150     WP_35 - <NA>     16
# 839           WP_114     16
# 876            WP_20     16
# 739  WP_103 - WP_103     16
# 510    WP_42 - WP_42     16
# 24    WP_16 - WP_152     15
# 337    WP_67 - WP_80     15
# 427   WP_152 - WP_46     15
# 575           WP_109     15
# 578           WP_104     15
# 340           WP_107     15
# 595    WP_76 - WP_80     15
# 877    WP_20 - WP_20     15
# 840  WP_114 - WP_114     15
# 419    WP_120 - WP_4     15
# 118           WP_113     14
# 398    WP_0 - WP_152     14
# 199  WP_149 - WP_152     14
# 576  WP_109 - WP_109     14
# 740            WP_40     14
# 570           WP_151     14
# 610    WP_90 - WP_94     14
# 475  WP_136 - WP_120     14
# 113           WP_100     14
# 425    WP_53 - WP_46     14
# 511    WP_43 - WP_43     14
# 226            WP_55     14
# 114            WP_17     14
# 424  WP_148 - WP_149     13
# 262    WP_89 - WP_88     13
# 227    WP_55 - WP_55     13
# 741    WP_40 - WP_40     13
# 116            WP_18     13
# 115    WP_17 - WP_17     13
# 485            WP_21     13
# 332            WP_56     13
# 429            WP_51     13
# 670            WP_62     13
# 832            WP_84     13
# 117  WP_100 - WP_100     13
# 833    WP_84 - WP_84     12
# 611     WP_94 - <NA>     12
# 637            WP_58     12
# 638            WP_71     12
# 486    WP_21 - WP_21     12
# 409   WP_11 - WP_120     12
# 423  WP_149 - WP_148     12
# 435           WP_150     12
# 119    WP_18 - WP_18     12
# 120  WP_113 - WP_113     12
# 530    WP_75 - WP_75     12
# 571  WP_151 - WP_151     12
# 430    WP_51 - WP_51     12
# 266           WP_108     12
# 580  WP_104 - WP_104     12
# 433           WP_122     11
# 10       WP_0 - WP_0     11
# 260    WP_88 - WP_89     11
# 311  WP_152 - WP_149     11
# 639    WP_71 - WP_71     11
# 640    WP_58 - WP_58     11
# 158           WP_135     11
# 596    WP_80 - WP_76     11
# 52             WP_98     11
# 513    WP_54 - WP_54     11
# 742            WP_39     11
# 743    WP_39 - WP_39     10
# 436  WP_150 - WP_150     10
# 448    WP_80 - WP_11     10
# 240           WP_117     10
# 191           WP_147     10
# 53     WP_98 - WP_98      9
# 587    WP_89 - WP_89      9
# 813           WP_124      9
# 514    WP_54 - WP_48      9
# 234  WP_121 - WP_120      9
# 671    WP_62 - WP_62      9
# 163  WP_135 - WP_135      9
# 482    WP_136 - <NA>      9
# 397    WP_1 - WP_152      9
# 434  WP_122 - WP_122      9
# 401    WP_152 - WP_2      9
# 286    WP_36 - WP_36      9
# 884            WP_26      8
# 418    WP_4 - WP_120      8
# 585     <NA> - WP_74      8
# 814  WP_124 - WP_124      8
# 212     WP_96 - <NA>      8
# 517    WP_48 - WP_42      8
# 518    WP_37 - WP_72      8
# 242  WP_117 - WP_117      8
# 515    WP_43 - WP_54      8
# 431            WP_78      8
# 381    WP_74 - WP_67      8
# 387    WP_80 - WP_67      8
# 516    WP_72 - WP_37      8
# 416   WP_30 - WP_120      8
# 672   WP_106 - WP_66      8
# 534    WP_75 - WP_80      7
# 563            WP_28      7
# 121            WP_79      7
# 335    WP_95 - WP_96      7
# 237  WP_120 - WP_121      7
# 885    WP_26 - WP_26      7
# 487            WP_14      7
# 673    WP_66 - WP_63      7
# 367    WP_87 - WP_96      7
# 674   WP_66 - WP_106      7
# 675    WP_77 - WP_66      7
# 449     WP_4 - WP_80      7
# 303  WP_146 - WP_152      7
# 345  WP_107 - WP_107      7
# 145     WP_4 - WP_35      7
# 422   WP_53 - WP_152      7
# 641            WP_65      7
# 336    WP_56 - WP_61      7
# 432    WP_78 - WP_78      7
# 677   WP_66 - WP_107      6
# 676    WP_66 - WP_90      6
# 428  WP_149 - WP_120      6
# 495     WP_4 - WP_30      6
# 125    WP_79 - WP_79      6
# 45      <NA> - WP_96      6
# 855           WP_132      6
# 420  WP_120 - WP_149      6
# 613    WP_94 - WP_63      6
# 488    WP_14 - WP_14      6
# 124            WP_10      6
# 338    WP_61 - WP_87      6
# 213   WP_152 - WP_96      6
# 600    WP_74 - WP_76      6
# 577           WP_142      6
# 792     WP_13 - WP_7      6
# 564    WP_28 - WP_28      6
# 339    WP_56 - WP_56      6
# 642            WP_64      6
# 521    WP_37 - WP_43      6
# 520    WP_42 - WP_37      6
# 744            WP_38      6
# 59      WP_66 - <NA>      5
# 92      <NA> - WP_35      5
# 678    WP_63 - WP_66      5
# 856  WP_132 - WP_132      5
# 622           WP_111      5
# 597    WP_80 - WP_75      5
# 196  WP_147 - WP_147      5
# 579  WP_142 - WP_142      5
# 236     <NA> - WP_11      5
# 523    WP_67 - WP_74      5
# 30             WP_29      5
# 259     <NA> - WP_88      5
# 63    WP_152 - WP_36      5
# 522    WP_81 - WP_80      5
# 468   WP_13 - WP_152      5
# 643    WP_65 - WP_65      5
# 415   WP_120 - WP_30      5
# 745    WP_38 - WP_38      5
# 126    WP_10 - WP_10      5
# 214   WP_96 - WP_152      5
# 615    WP_63 - WP_90      5
# 710    <NA> - WP_136      5
# 343    WP_61 - WP_86      5
# 342            WP_57      5
# 341    WP_86 - WP_95      5
# 357    WP_90 - WP_77      5
# 347    WP_96 - WP_46      5
# 369    WP_96 - WP_87      5
# 349    WP_96 - WP_68      4
# 546    WP_72 - WP_75      4
# 101    WP_11 - WP_96      4
# 346    WP_57 - WP_57      4
# 31     WP_29 - WP_29      4
# 34      <NA> - WP_80      4
# 527    WP_72 - WP_81      4
# 614    WP_63 - WP_94      4
# 598    WP_72 - WP_76      4
# 526    WP_45 - WP_43      4
# 88      WP_11 - WP_4      4
# 348    WP_68 - WP_67      4
# 222    WP_0 - WP_149      4
# 61     WP_36 - WP_46      4
# 60    WP_66 - WP_152      4
# 96      WP_11 - <NA>      4
# 466    WP_11 - WP_13      4
# 251   WP_106 - WP_96      4
# 574  WP_152 - WP_146      4
# 644    WP_64 - WP_64      4
# 586   WP_74 - WP_152      4
# 645            WP_59      4
# 646    WP_70 - WP_74      4
# 681   WP_66 - WP_108      4
# 269  WP_108 - WP_108      4
# 680   WP_108 - WP_66      4
# 273     <NA> - WP_89      4
# 793     <NA> - WP_13      4
# 404  WP_126 - WP_152      4
# 794     WP_7 - WP_13      4
# 679   WP_107 - WP_66      4
# 344    WP_46 - WP_56      4
# 623  WP_111 - WP_111      4
# 241  WP_116 - WP_120      3
# 301      <NA> - WP_4      3
# 350    WP_30 - WP_80      3
# 57      <NA> - WP_46      3
# 682    WP_62 - WP_66      3
# 50    WP_36 - WP_152      3
# 246     <NA> - WP_61      3
# 531    WP_44 - WP_37      3
# 219   WP_120 - WP_16      3
# 179    <NA> - WP_146      3
# 352    WP_80 - WP_90      3
# 528    WP_74 - WP_72      3
# 529    WP_37 - WP_80      3
# 97       WP_4 - <NA>      3
# 353   WP_87 - WP_106      3
# 354    WP_32 - WP_30      3
# 797     WP_6 - WP_13      3
# 796     WP_13 - WP_6      3
# 359    WP_80 - WP_30      3
# 647    WP_59 - WP_59      3
# 356    WP_86 - WP_90      3
# 355    WP_77 - WP_86      3
# 70      <NA> - WP_77      3
# 478           WP_112      3
# 351    WP_80 - WP_32      3
# 157           WP_140      3
# 474     WP_13 - <NA>      3
# 708  WP_125 - WP_126      3
# 866   WP_136 - WP_16      3
# 725   WP_149 - WP_35      3
# 457  WP_129 - WP_152      3
# 470   WP_152 - WP_13      3
# 254  WP_120 - WP_116      3
# 271     <NA> - WP_90      3
# 292   WP_152 - WP_66      3
# 648    WP_76 - WP_70      2
# 362   WP_108 - WP_87      2
# 561    WP_86 - WP_87      2
# 649    WP_76 - WP_81      2
# 363    WP_87 - WP_90      2
# 361    WP_87 - WP_61      2
# 210     <NA> - WP_73      2
# 62     WP_98 - WP_66      2
# 801   WP_13 - WP_149      2
# 802   WP_149 - WP_13      2
# 289    <NA> - WP_148      2
# 402      <NA> - WP_0      2
# 102    WP_96 - WP_80      2
# 270   WP_77 - WP_108      2
# 599    WP_75 - WP_76      2
# 264  WP_116 - WP_152      2
# 704  WP_133 - WP_152      2
# 703  WP_126 - WP_133      2
# 294     <NA> - WP_93      2
# 702    <NA> - WP_129      2
# 812    WP_120 - WP_0      2
# 364    WP_46 - WP_61      2
# 365   WP_107 - WP_87      2
# 762    <NA> - WP_131      2
# 153   WP_16 - WP_136      2
# 99      WP_80 - WP_4      2
# 795      WP_7 - <NA>      2
# 276    WP_120 - WP_8      2
# 195  WP_149 - WP_118      2
# 285  WP_152 - WP_129      2
# 591    WP_152 - WP_3      2
# 634  WP_145 - WP_152      2
# 857  WP_133 - WP_130      2
# 784  WP_101 - WP_149      2
# 861  WP_146 - WP_144      2
# 408     WP_88 - <NA>      2
# 785   WP_99 - WP_101      2
# 406  WP_152 - WP_123      2
# 405   WP_88 - WP_152      2
# 198  WP_152 - WP_148      2
# 707    <NA> - WP_125      2
# 358    WP_87 - WP_95      2
# 200     WP_70 - <NA>      2
# 275   WP_89 - WP_120      2
# 205    WP_50 - WP_49      2
# 69       WP_5 - <NA>      2
# 274   WP_152 - WP_89      2
# 573  WP_151 - WP_152      2
# 68       <NA> - WP_5      2
# 65     WP_46 - WP_36      2
# 360   WP_80 - WP_106      2
# 540    WP_80 - WP_37      2
# 541     <NA> - WP_48      2
# 536    WP_48 - WP_43      2
# 539     WP_48 - <NA>      2
# 218  WP_147 - WP_152      2
# 140  WP_130 - WP_133      2
# 223   WP_149 - WP_16      2
# 456  WP_144 - WP_152      2
# 81      WP_80 - <NA>      2
# 233  WP_152 - WP_121      2
# 890      WP_8 - <NA>      2
# 459  WP_146 - WP_149      2
# 462  WP_123 - WP_152      2
# 497     WP_30 - WP_4      2
# 496    WP_30 - WP_35      2
# 302   WP_16 - WP_146      2
# 822  WP_110 - WP_152      2
# 306  WP_133 - WP_120      2
# 252    WP_96 - WP_66      2
# 465    WP_35 - WP_53      2
# 871     WP_16 - <NA>      2
# 471    WP_46 - WP_35      2
# 472    WP_13 - WP_11      2
# 164  WP_135 - WP_136      2
# 683    WP_66 - WP_62      2
# 684    WP_63 - WP_62      2
# 616    WP_93 - WP_94      2
# 479  WP_112 - WP_112      2
# 538    WP_43 - WP_44      2
# 764  WP_149 - WP_146      2
# 696    <NA> - WP_119      2
# 865  WP_136 - WP_146      2
# 537     WP_54 - <NA>      2
# 249   WP_96 - WP_106      2
# 535    WP_37 - WP_45      2
# 366    WP_90 - WP_95      2
# 533    WP_43 - WP_37      2
# 532    WP_37 - WP_54      2
# 717    WP_12 - WP_11      2
# 368    WP_87 - WP_46      2
# 718   WP_11 - WP_149      2
# 446  WP_150 - WP_152      2
# 263     WP_89 - <NA>      2
# 370    WP_87 - WP_56      2
# 216     WP_11 - WP_0      2
# 889     WP_25 - <NA>      2
# 297    <NA> - WP_123      2
# 763    WP_131 - <NA>      2
# 451    WP_80 - WP_96      2
# 181  WP_139 - WP_152      2
# 774  WP_152 - WP_128      2
# 773    WP_128 - <NA>      2
# 293      WP_4 - WP_5      2
# 751    WP_39 - WP_33      1
# 753     <NA> - WP_34      1
# 754    WP_33 - WP_41      1
# 752     WP_40 - <NA>      1
# 859  WP_132 - WP_133      1
# 750    WP_38 - WP_39      1
# 722   WP_149 - WP_80      1
# 142  WP_127 - WP_126      1
# 143  WP_126 - WP_113      1
# 727    WP_11 - WP_12      1
# 726   WP_35 - WP_149      1
# 724    WP_52 - WP_12      1
# 723    WP_149 - WP_1      1
# 721    WP_96 - WP_52      1
# 893     <NA> - WP_25      1
# 720    WP_30 - WP_96      1
# 719   WP_149 - WP_11      1
# 144   WP_133 - WP_79      1
# 895   WP_91 - WP_123      1
# 146     WP_9 - WP_11      1
# 147   WP_100 - WP_82      1
# 894     <NA> - WP_91      1
# 892     <NA> - WP_24      1
# 749   WP_152 - WP_38      1
# 133   WP_120 - WP_18      1
# 748     WP_22 - <NA>      1
# 747   WP_149 - WP_22      1
# 746    WP_41 - WP_40      1
# 888    WP_26 - WP_25      1
# 756  WP_103 - WP_146      1
# 132   WP_79 - WP_127      1
# 134    WP_18 - WP_10      1
# 891      WP_8 - WP_8      1
# 135    WP_10 - WP_17      1
# 136    WP_17 - WP_11      1
# 137     WP_4 - WP_92      1
# 138    WP_92 - WP_91      1
# 139   WP_91 - WP_130      1
# 141  WP_113 - WP_120      1
# 755   WP_34 - WP_103      1
# 64     WP_46 - WP_98      1
# 757    WP_69 - WP_34      1
# 869   WP_119 - WP_16      1
# 835   WP_105 - WP_84      1
# 834    <NA> - WP_105      1
# 42     WP_30 - WP_29      1
# 44     WP_29 - WP_90      1
# 867  WP_144 - WP_146      1
# 48     WP_61 - WP_36      1
# 868   WP_16 - WP_145      1
# 827   WP_97 - WP_152      1
# 837   WP_85 - WP_105      1
# 870     WP_11 - WP_9      1
# 826    WP_16 - WP_97      1
# 872    <NA> - WP_104      1
# 823    <NA> - WP_151      1
# 873  WP_104 - WP_110      1
# 874  WP_152 - WP_135      1
# 875   WP_146 - WP_16      1
# 836    WP_84 - WP_85      1
# 838  WP_105 - WP_152      1
# 21     WP_23 - WP_19      1
# 850  WP_143 - WP_138      1
# 860  WP_120 - WP_132      1
# 862  WP_144 - WP_147      1
# 854   WP_16 - WP_144      1
# 863  WP_147 - WP_136      1
# 864  WP_146 - WP_136      1
# 852  WP_136 - WP_143      1
# 851  WP_138 - WP_152      1
# 849  WP_104 - WP_136      1
# 40     WP_31 - WP_30      1
# 848  WP_152 - WP_104      1
# 845   WP_73 - WP_120      1
# 38     WP_74 - WP_31      1
# 843  WP_115 - WP_120      1
# 842  WP_114 - WP_115      1
# 841   WP_16 - WP_114      1
# 39      WP_31 - <NA>      1
# 23      WP_19 - <NA>      1
# 878     <NA> - WP_20      1
# 758    WP_34 - WP_69      1
# 779    WP_148 - <NA>      1
# 803   WP_46 - WP_149      1
# 858  WP_130 - WP_120      1
# 788  WP_149 - WP_133      1
# 787  WP_149 - WP_101      1
# 786   WP_101 - WP_99      1
# 72    WP_77 - WP_120      1
# 79     WP_136 - WP_8      1
# 778    <NA> - WP_147      1
# 805   WP_149 - WP_83      1
# 777  WP_102 - WP_146      1
# 776   WP_27 - WP_102      1
# 775   WP_152 - WP_27      1
# 100   WP_152 - WP_80      1
# 766   WP_16 - WP_149      1
# 765    WP_118 - <NA>      1
# 759  WP_133 - WP_149      1
# 804    WP_35 - WP_46      1
# 806   WP_83 - WP_149      1
# 821   WP_73 - WP_110      1
# 816  WP_117 - WP_152      1
# 818  WP_124 - WP_152      1
# 817  WP_152 - WP_124      1
# 879    WP_20 - WP_23      1
# 880     WP_23 - <NA>      1
# 148  WP_120 - WP_100      1
# 881     <NA> - WP_19      1
# 19     WP_24 - WP_23      1
# 18    WP_152 - WP_24      1
# 807  WP_149 - WP_102      1
# 886    WP_23 - WP_24      1
# 887     <NA> - WP_26      1
# 815  WP_149 - WP_117      1
# 811      <NA> - WP_1      1
# 810     WP_8 - WP_16      1
# 809     WP_16 - WP_8      1
# 808   WP_102 - WP_99      1
# 317    WP_35 - WP_36      1
# 176  WP_133 - WP_141      1
# 149     WP_82 - WP_9      1
# 458  WP_120 - WP_122      1
# 481  WP_112 - WP_152      1
# 480  WP_152 - WP_112      1
# 477      WP_4 - WP_4      1
# 476      WP_5 - WP_4      1
# 473    WP_35 - WP_13      1
# 469    WP_53 - WP_35      1
# 463     <NA> - WP_30      1
# 461  WP_148 - WP_146      1
# 460  WP_122 - WP_152      1
# 253    WP_66 - WP_96      1
# 553    WP_48 - WP_54      1
# 454  WP_152 - WP_144      1
# 453   WP_77 - WP_152      1
# 450    WP_11 - WP_80      1
# 445    WP_53 - WP_51      1
# 444  WP_152 - WP_150      1
# 443   WP_78 - WP_152      1
# 442   WP_152 - WP_74      1
# 441    WP_51 - WP_78      1
# 440    WP_74 - WP_96      1
# 245  WP_117 - WP_116      1
# 244  WP_121 - WP_117      1
# 243    <NA> - WP_116      1
# 489     <NA> - WP_14      1
# 551    WP_80 - WP_45      1
# 550    WP_42 - WP_45      1
# 549    WP_48 - WP_45      1
# 548    WP_74 - WP_75      1
# 547    WP_48 - WP_44      1
# 545    WP_37 - WP_81      1
# 544    WP_80 - WP_54      1
# 543    WP_43 - WP_45      1
# 542    WP_45 - WP_37      1
# 215    WP_96 - WP_11      1
# 217   WP_16 - WP_147      1
# 220     WP_0 - WP_11      1
# 228    WP_60 - WP_55      1
# 229    WP_55 - WP_60      1
# 230   WP_60 - WP_120      1
# 494    WP_149 - WP_0      1
# 492    WP_21 - WP_63      1
# 491    WP_15 - WP_21      1
# 490    WP_14 - WP_15      1
# 439   WP_96 - WP_149      1
# 438  WP_122 - WP_120      1
# 437   WP_11 - WP_122      1
# 385   WP_90 - WP_107      1
# 383   WP_106 - WP_87      1
# 382  WP_106 - WP_107      1
# 380    WP_32 - WP_74      1
# 379    WP_96 - WP_32      1
# 378    WP_47 - WP_46      1
# 377    WP_57 - WP_96      1
# 376    WP_86 - WP_57      1
# 375    WP_96 - WP_47      1
# 374    WP_47 - WP_61      1
# 373    WP_86 - WP_47      1
# 371    WP_61 - WP_56      1
# 295   WP_93 - WP_152      1
# 296    WP_123 - <NA>      1
# 298    WP_67 - WP_70      1
# 299    WP_66 - WP_93      1
# 300    WP_93 - WP_66      1
# 307   WP_16 - WP_133      1
# 308  WP_120 - WP_115      1
# 309  WP_115 - WP_113      1
# 384    WP_95 - WP_87      1
# 386    WP_95 - WP_61      1
# 267   WP_108 - WP_46      1
# 388    WP_32 - WP_80      1
# 272  WP_152 - WP_116      1
# 421    WP_30 - WP_53      1
# 278    WP_2 - WP_120      1
# 281    <NA> - WP_134      1
# 282   WP_152 - WP_61      1
# 283     WP_61 - <NA>      1
# 411   WP_89 - WP_152      1
# 410    WP_46 - WP_88      1
# 407   WP_123 - WP_88      1
# 403  WP_152 - WP_126      1
# 287     WP_36 - <NA>      1
# 396    WP_90 - WP_86      1
# 395   WP_90 - WP_108      1
# 394   WP_120 - WP_46      1
# 393  WP_106 - WP_108      1
# 392   WP_46 - WP_120      1
# 391     <NA> - WP_86      1
# 390    WP_90 - WP_87      1
# 389    WP_30 - WP_32      1
# 552    WP_45 - WP_80      1
# 554    WP_54 - WP_43      1
# 709  WP_126 - WP_125      1
# 654    WP_64 - WP_70      1
# 663    WP_58 - WP_59      1
# 662    WP_76 - WP_71      1
# 661     WP_70 - WP_3      1
# 660     WP_65 - <NA>      1
# 659    WP_81 - WP_74      1
# 658    WP_64 - WP_65      1
# 657    WP_74 - WP_64      1
# 656     WP_3 - WP_70      1
# 655     WP_76 - WP_3      1
# 653    WP_76 - WP_64      1
# 555    WP_42 - WP_44      1
# 652    WP_74 - WP_70      1
# 651     WP_3 - WP_74      1
# 650    WP_70 - WP_76      1
# 161  WP_140 - WP_136      1
# 162  WP_136 - WP_135      1
# 636  WP_120 - WP_148      1
# 635  WP_141 - WP_152      1
# 633  WP_152 - WP_141      1
# 632  WP_152 - WP_140      1
# 664    WP_65 - WP_58      1
# 665     <NA> - WP_65      1
# 666    WP_71 - WP_70      1
# 667    WP_81 - WP_75      1
# 154  WP_136 - WP_141      1
# 701   WP_147 - WP_73      1
# 700  WP_152 - WP_147      1
# 699   WP_120 - WP_96      1
# 698  WP_143 - WP_146      1
# 697  WP_119 - WP_143      1
# 155  WP_141 - WP_136      1
# 693    WP_66 - WP_98      1
# 692    WP_107 - <NA>      1
# 691    WP_86 - WP_66      1
# 690   WP_106 - WP_86      1
# 689    WP_90 - WP_63      1
# 688   WP_77 - WP_106      1
# 687     WP_77 - <NA>      1
# 686  WP_108 - WP_106      1
# 685    WP_62 - WP_63      1
# 159  WP_136 - WP_140      1
# 160  WP_140 - WP_140      1
# 668    WP_59 - WP_74      1
# 631  WP_152 - WP_145      1
# 630  WP_140 - WP_152      1
# 629  WP_143 - WP_152      1
# 592      WP_3 - <NA>      1
# 197  WP_148 - WP_147      1
# 584  WP_104 - WP_152      1
# 583  WP_109 - WP_104      1
# 582  WP_142 - WP_109      1
# 581  WP_152 - WP_142      1
# 206   WP_16 - WP_120      1
# 572  WP_152 - WP_151      1
# 207   WP_120 - WP_50      1
# 208    WP_49 - WP_50      1
# 569      WP_2 - <NA>      1
# 568  WP_129 - WP_150      1
# 567   WP_73 - WP_129      1
# 566   WP_28 - WP_152      1
# 565     <NA> - WP_28      1
# 562      WP_0 - <NA>      1
# 209    WP_49 - WP_35      1
# 558    WP_44 - WP_45      1
# 557    WP_45 - WP_72      1
# 556    WP_72 - WP_44      1
# 590    <NA> - WP_139      1
# 194  WP_147 - WP_149      1
# 171    <NA> - WP_133      1
# 193    WP_81 - WP_70      1
# 627  WP_152 - WP_143      1
# 172  WP_137 - WP_120      1
# 625  WP_111 - WP_152      1
# 624    <NA> - WP_111      1
# 621    WP_46 - WP_53      1
# 620    WP_94 - WP_93      1
# 619    WP_94 - WP_90      1
# 618    WP_77 - WP_63      1
# 617    WP_77 - WP_93      1
# 173  WP_146 - WP_145      1
# 174  WP_145 - WP_137      1
# 175  WP_141 - WP_146      1
# 310  WP_113 - WP_133      1
# 180  WP_146 - WP_139      1
# 604    WP_75 - WP_67      1
# 603     WP_76 - <NA>      1
# 602    WP_76 - WP_72      1
# 601    WP_75 - WP_72      1
# 192   WP_118 - WP_81      1
# 896     WP_73 - <NA>      1

# %%
display(concatDF[concatDF['Route'].isnull()])
concatDF = concatDF[concatDF['Route'].notna()]
display(concatDF[concatDF['Route'].isnull()])
# Out:
#         MMSI        BaseDateTime      LAT       LON   SOG    COG  Heading  \
# 0  182083130 2019-02-28 09:28:52  22.5822 -155.6414  55.8   31.9    490.0
# 0  189750956 2019-01-25 08:13:49  20.6338 -155.6523  56.7  299.9     37.0
# 0  305367161 2019-01-28 12:15:02  21.8343 -155.4291  11.4  262.6    257.0
# 0  338326458 2019-01-29 23:36:58  21.3063 -157.8633   0.0  135.5    151.0
# 0  338593071 2019-01-28 07:07:09  21.3201 -157.8671   0.0  361.0    511.0
# 0  366122928 2019-01-05 16:45:44  21.1444 -157.6381   8.0  297.2    299.0
# 0  366294424 2019-03-22 03:54:49  21.3148 -157.8772   0.0  322.8    511.0
# 0  366299856 2019-01-20 06:24:58  21.3119 -157.8779   9.7  166.1    122.0
# 0  366932155 2019-03-13 19:02:33  21.3101 -157.8679   9.6  354.2    161.0
# 0  367248818 2019-02-01 20:43:31  21.2804 -157.8382   0.1  133.7    511.0
# 0  367339960 2019-02-05 22:13:49  20.8747 -156.6994   9.1  310.5    511.0
# 0  367513910 2019-01-16 20:01:46  21.3036 -158.0802   0.0  348.0    511.0
# 0  368728008 2019-03-06 09:44:24  20.8850 -156.7232   7.2  336.0    340.0
# 0  412110153 2019-01-04 23:58:14  20.5514 -157.6570  33.7  136.8    137.0
# 0  412110157 2019-01-05 09:40:34  19.4650 -156.9586  34.7  155.3    155.0
# 0  412110159 2019-01-04 21:44:16  20.7802 -157.8525  84.5  146.5    146.0
# 0  412110160 2019-01-03 19:14:30  19.0339 -156.4391  84.1  320.9    319.0
# 0  412110166 2019-01-05 08:44:36  19.5907 -157.0284  85.9  154.3    154.0
# 0  412110174 2019-01-03 20:36:32  19.1660 -156.5395  83.6  325.3    325.0
# 0  412110176 2019-01-04 20:26:18  20.9174 -157.9584   8.4  148.4    144.0
# 0  412110184 2019-01-05 11:40:35  19.1833 -156.8034  61.0  150.2    150.0
# 0  412110188 2019-01-05 09:17:04  19.5178 -156.9885  34.9  155.1    152.0
# 0  412110204 2019-01-04 20:00:17  20.9656 -157.9960  59.3  131.3    131.0
# 0  412110205 2019-01-05 08:14:36  19.6562 -157.0633  60.6  150.0    150.0
# 0  412110206 2019-01-05 05:24:09  19.9858 -157.2765  33.4  147.2    147.0
# 0  518084021 2019-01-27 18:59:27  21.3103 -157.8728   0.0  249.0     49.0
# 0  903820791 2019-01-05 12:43:33  21.4107 -157.4383   6.3   45.1     63.0
# 0  941206597 2019-03-15 21:32:42  20.3007 -155.6978   1.9  116.8    511.0
# 0  941206643 2019-01-22 21:16:48  21.3136 -157.8641   1.9   85.0    511.0
# 0  972601468 2019-03-18 19:26:37  21.3283 -158.1197   1.1  162.5    511.0
# 0  972601491 2019-03-18 19:30:03  21.3283 -158.1197   0.0    0.0    511.0
# 0  972601517 2019-03-18 19:28:12  21.3284 -158.1197   0.0  147.4    511.0
# 0  972601537 2019-03-18 19:21:38  21.3284 -158.1197   0.1    0.0    511.0
# 0  972601569 2019-03-18 19:24:37  21.3283 -158.1197   0.0    0.0    511.0
# 0  972971670 2019-01-21 21:38:46  20.8970 -156.4671   0.1    0.0    511.0
# 0  972971671 2019-01-21 22:45:35  20.8974 -156.4666   0.2    0.0    511.0
# 0  972971673 2019-01-21 21:48:23  20.8971 -156.4670   0.1    0.0    511.0
# 0  972971674 2019-01-21 23:20:30  20.8971 -156.4672   0.8    0.0    511.0
# 0  981000601 2019-03-16 00:40:52  22.5977 -156.7781   1.1   70.0    511.0
#
#     VesselName  VesselType  Status  Length  Width  Draft  IsClassA  Avg_Speed  \
# 0         <NA>           0      99       0      0    NaN     False       55.8
# 0         <NA>           0      99       0      0    NaN     False       56.7
# 0         <NA>           0       0       0      0    NaN      True       11.4
# 0         <NA>           0       0       0      0    NaN      True        0.0
# 0         <NA>           0       0       0      0    NaN      True        0.0
# 0         <NA>           0       0       0      0    NaN      True        8.0
# 0         <NA>           0      99       0      0    NaN     False        0.0
# 0         <NA>           0       0       0      0    NaN      True        9.7
# 0         <NA>           0       8       0      0    NaN      True        9.6
# 0         <NA>           0       0       0      0    NaN      True        0.1
# 0         <NA>           0      99       0      0    NaN     False        9.1
# 0  RESPONSE 41          54      99       8      0    NaN     False        0.0
# 0         <NA>           0       8       0      0    NaN      True        7.2
# 0         <NA>           0      99       0      0    NaN     False       33.7
# 0         <NA>           0      99       0      0    NaN     False       34.7
# 0         <NA>           0      99       0      0    NaN     False       84.5
# 0         <NA>           0      99       0      0    NaN     False       84.1
# 0         <NA>           0      99       0      0    NaN     False       85.9
# 0         <NA>           0      99       0      0    NaN     False       83.6
# 0         <NA>           0      99       0      0    NaN     False        8.4
# 0         <NA>           0      99       0      0    NaN     False       61.0
# 0         <NA>           0      99       0      0    NaN     False       34.9
# 0         <NA>           0      99       0      0    NaN     False       59.3
# 0         <NA>           0      99       0      0    NaN     False       60.6
# 0         <NA>           0      99       0      0    NaN     False       33.4
# 0         <NA>           0       9       0      0    NaN      True        0.0
# 0         <NA>           0      11       0      0    NaN      True        6.3
# 0         <NA>           0      99       0      0    NaN     False        1.9
# 0         <NA>           0      99       0      0    NaN     False        1.9
# 0         <NA>           0      15       0      0    NaN      True        1.1
# 0         <NA>           0      15       0      0    NaN      True        0.0
# 0         <NA>           0      15       0      0    NaN      True        0.0
# 0         <NA>           0      15       0      0    NaN      True        0.1
# 0         <NA>           0      15       0      0    NaN      True        0.0
# 0         <NA>           0      15       0      0    NaN      True        0.1
# 0         <NA>           0      15       0      0    NaN      True        0.2
# 0         <NA>           0      15       0      0    NaN      True        0.1
# 0         <NA>           0      15       0      0    NaN      True        0.8
# 0         <NA>           0      99       0      0    NaN     False        1.1
#
#   EstimatedStatus  IsInWP IsInSignificantWP Route
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit   WP_96              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit    None              <NA>  <NA>
# 0            exit  WP_152              <NA>  <NA>
# 0            exit  WP_120              <NA>  <NA>
# 0            exit  WP_120              <NA>  <NA>
# 0            exit  WP_120              <NA>  <NA>
# 0            exit  WP_120              <NA>  <NA>
# 0            exit  WP_120              <NA>  <NA>
# 0            exit   WP_35              <NA>  <NA>
# 0            exit   WP_35              <NA>  <NA>
# 0            exit   WP_35              <NA>  <NA>
# 0            exit   WP_35              <NA>  <NA>
# 0            exit    WP_0              <NA>  <NA>
# Empty DataFrame
# Columns: [MMSI, BaseDateTime, LAT, LON, SOG, COG, Heading, VesselName, VesselType, Status, Length, Width, Draft, IsClassA, Avg_Speed, EstimatedStatus, IsInWP, IsInSignificantWP, Route]
# Index: []

# %%
# column of booleans. If true, then the point belongs to a route, false otherwise
concatDF['IsInRoute'] = concatDF['Route'].str.contains('-')

# plot all points given a certain route
# ----- Specify route name here --------
#route_name = 'WP_61' + ' - ' + 'WP_96'
route_name = 'WP_152' + ' - ' + 'WP_120'
# ----- changing the dataset often requires to change the route name above -----
chosen_points = concatDF[concatDF['Route'] == route_name].copy()
#f.plot_routes(chosen_points, clusteredPointsDF, mode='SingleRoute')
tempplot = f.route_arrows_plot(inputDF=chosen_points.head(int((chosen_points.size))), color_criteria='Avg_Speed', scale_factor=0.000000000005)
po.plot(tempplot, auto_open=True)

# create a list of Dataframes (each representing a single route)
# compare a value of 'IsInRoute' with the following one. If the opposite (~) of the second is different,
# then set the value of 'group' as '1' (boolean True converted to int. Int8 is chosen to save memory)
concatDF['group'] = concatDF['group'] = (concatDF['IsInRoute'] & (~concatDF['IsInRoute'].shift(1, fill_value=False))).astype(p.Int8Dtype())
# calculate the cumulative sum of each group. Every time a new '1' is found, the cumsum is increased
concatDF['trip_id'] = concatDF['group'].cumsum() # trip_id is basically the id of each route
# Extract only the points for which "IsInRoute" is set to True and also belong to the specified route
only_route_points = concatDF[(concatDF['IsInRoute'] == True) & (concatDF['Route'] == route_name)]
# group route points by their trip_id and save each resulting group_data separately into a list
list_of_trips = [route for _, route in only_route_points.groupby('trip_id')]
concatDF.drop('group', axis=1)
# check the list of routes before exporting it
lengths = [len(x) for x in list_of_trips]
print(f"mean: {s.mean(lengths)}, median: {s.median(lengths)}, min: {min(lengths)}, max: {max(lengths)}: routes: {len(lengths)}, moda: {s.mode(lengths)}")
# Out:
# mean: 110.59358288770053, median: 96, min: 41, max: 524: routes: 187, moda: 78

# %%
# print five random trips to check that the code above works properly
from random import sample
indexes = sample(range(0, len(list_of_trips)), 5)

for i in indexes:
    f.route_plot(inputDF=list_of_trips[i],
                 title=f'Index: {i}, Test {list_of_trips[i].iloc[0,list_of_trips[i].columns.get_loc("MMSI")]}',
                 color_criteria='Avg_Speed',
                 hover_data=['MMSI'])

# %%
# Check how many vessels partecipate to the chosen route
test_groupby = only_route_points.groupby('MMSI')['MMSI'].count().reset_index(name='count')
display(test_groupby.sort_values(by="count", ascending=False))
print(f'There are {test_groupby["MMSI"].shape[0]} different vessels that take this route:\n{test_groupby["MMSI"].to_list()}')
f.route_plot(inputDF=only_route_points[only_route_points['MMSI'] == 367309860], color_criteria="Avg_Speed")
# Out:
#          MMSI  count
# 23  367309860   3168
# 28  367416420   2007
# 16  367008740   1890
# 29  367420170   1758
# 27  367389160   1223
# 30  367472000   1066
# 34  367776660    971
# 18  367017630    924
# 9   366873510    837
# 26  367310270    724
# 12  366972620    718
# 21  367151310    467
# 8   366766970    354
# 13  366999665    349
# 25  367310240    331
# 5   338242587    309
# 4   338210969    281
# 6   338272000    241
# 15  367007920    222
# 38  518100014    192
# 33  367730340    175
# 42  538004472    174
# 36  368477000    171
# 17  367008770    135
# 22  367309120    127
# 3   338115054    127
# 0   245011000    125
# 24  367309890    125
# 7   356774000    124
# 32  367648550    124
# 40  518100405    123
# 2   311017100    117
# 39  518100015    117
# 37  477229900    114
# 1   303174000    109
# 41  538004149     98
# 11  366953000     91
# 19  367055690     88
# 14  367007870     87
# 10  366914410     82
# 20  367133450     78
# 35  367793430     73
# 31  367515670     65
# There are 43 different vessels that take this route:
# [245011000, 303174000, 311017100, 338115054, 338210969, 338242587, 338272000, 356774000, 366766970, 366873510, 366914410, 366953000, 366972620, 366999665, 367007870, 367007920, 367008740, 367008770, 367017630, 367055690, 367133450, 367151310, 367309120, 367309860, 367309890, 367310240, 367310270, 367389160, 367416420, 367420170, 367472000, 367515670, 367648550, 367730340, 367776660, 367793430, 368477000, 477229900, 518100014, 518100015, 518100405, 538004149, 538004472]

# %%
display(list_of_trips[2].head(5))
display(list_of_trips[2].tail(5))
display(concatDF.head(5))

# Save the result to a binary pickle file so that it can be imported by the next ipynb
with open('../out/TREAD_out.pkl', 'wb') as file:
    pickle.dump((concatDF, list_of_trips, route_name), file)
# Out:
#            MMSI        BaseDateTime      LAT       LON  SOG   COG  Heading  \
# 2169  311017100 2019-01-06 18:16:40  21.3144 -157.8844  0.9  63.0    274.0
# 2170  311017100 2019-01-06 18:17:50  21.3145 -157.8840  1.2  75.0    269.0
# 2171  311017100 2019-01-06 18:19:10  21.3147 -157.8834  1.6  69.0    263.0
# 2172  311017100 2019-01-06 18:20:20  21.3150 -157.8829  1.8  53.0    248.0
# 2173  311017100 2019-01-06 18:21:30  21.3154 -157.8825  1.6  43.0    230.0
#
#        VesselName  VesselType  Status  ...  Draft  IsClassA  Avg_Speed  \
# 2169  GULF RASTAQ          80       0  ...   12.2      True       0.93
# 2170  GULF RASTAQ          80       0  ...   12.2      True       1.19
# 2171  GULF RASTAQ          80       0  ...   12.2      True       1.61
# 2172  GULF RASTAQ          80       0  ...   12.2      True       1.71
# 2173  GULF RASTAQ          80       0  ...   12.2      True       1.69
#
#       EstimatedStatus  IsInWP IsInSignificantWP            Route IsInRoute  \
# 2169          sailing  WP_152              <NA>  WP_152 - WP_120      True
# 2170          sailing  WP_152              <NA>  WP_152 - WP_120      True
# 2171          sailing  WP_152              <NA>  WP_152 - WP_120      True
# 2172          sailing  WP_152              <NA>  WP_152 - WP_120      True
# 2173          sailing  WP_152              <NA>  WP_152 - WP_120      True
#
#      group  trip_id
# 2169     1     1892
# 2170     0     1892
# 2171     0     1892
# 2172     0     1892
# 2173     0     1892
#
# [5 rows x 22 columns]
#            MMSI        BaseDateTime      LAT       LON  SOG    COG  Heading  \
# 2281  311017100 2019-01-06 21:11:01  21.3251 -158.1141  1.6  123.0    170.0
# 2282  311017100 2019-01-06 21:12:30  21.3248 -158.1136  1.2  112.0    195.0
# 2283  311017100 2019-01-06 21:13:51  21.3246 -158.1132  0.9  120.0    206.0
# 2284  311017100 2019-01-06 21:15:01  21.3244 -158.1129  1.0  133.0    216.0
# 2285  311017100 2019-01-06 21:17:01  21.3241 -158.1126  0.5  133.0    226.0
#
#        VesselName  VesselType  Status  ...  Draft  IsClassA  Avg_Speed  \
# 2281  GULF RASTAQ          80       0  ...   12.2      True       1.71
# 2282  GULF RASTAQ          80       0  ...   12.2      True       1.35
# 2283  GULF RASTAQ          80       0  ...   12.2      True       1.13
# 2284  GULF RASTAQ          80       0  ...   12.2      True       1.06
# 2285  GULF RASTAQ          80       0  ...   12.2      True       0.74
#
#       EstimatedStatus  IsInWP IsInSignificantWP            Route IsInRoute  \
# 2281          sailing  WP_120              <NA>  WP_152 - WP_120      True
# 2282          sailing  WP_120              <NA>  WP_152 - WP_120      True
# 2283          sailing  WP_120              <NA>  WP_152 - WP_120      True
# 2284          sailing  WP_120              <NA>  WP_152 - WP_120      True
# 2285          sailing  WP_120              <NA>  WP_152 - WP_120      True
#
#      group  trip_id
# 2281     0     1892
# 2282     0     1892
# 2283     0     1892
# 2284     0     1892
# 2285     0     1892
#
# [5 rows x 22 columns]
#      MMSI        BaseDateTime      LAT       LON  SOG    COG  Heading  \
# 0  382872 2019-01-08 19:32:26  21.3557 -157.9487  5.1  308.0    511.0
# 1  382872 2019-01-08 19:33:37  21.3569 -157.9501  5.2  316.5    511.0
# 2  382872 2019-01-08 19:34:47  21.3580 -157.9514  5.2  300.0    511.0
# 3  382872 2019-01-08 19:35:57  21.3584 -157.9532  5.2  274.0    511.0
# 4  382872 2019-01-08 19:37:07  21.3578 -157.9548  5.1  232.0    511.0
#
#   VesselName  VesselType  Status  ...  Draft  IsClassA  Avg_Speed  \
# 0    HARRIER           0      15  ...    0.0      True       5.10
# 1    HARRIER           0      15  ...    0.0      True       5.40
# 2    HARRIER           0      15  ...    0.0      True       5.06
# 3    HARRIER           0      15  ...    0.0      True       5.33
# 4    HARRIER           0      15  ...    0.0      True       4.97
#
#    EstimatedStatus  IsInWP IsInSignificantWP            Route IsInRoute group  \
# 0            entry  WP_149            WP_149           WP_149     False     0
# 1          sailing  WP_149              <NA>  WP_149 - WP_149      True     1
# 2          sailing  WP_149              <NA>  WP_149 - WP_149      True     0
# 3          sailing  WP_149              <NA>  WP_149 - WP_149      True     0
# 4          sailing  WP_149              <NA>  WP_149 - WP_149      True     0
#
#    trip_id
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 22 columns]
